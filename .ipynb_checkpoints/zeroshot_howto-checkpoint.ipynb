# %%
from train import *

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Current device:", device)
# Out:
# Current device: cuda

# %%
def lhs(size, lb=-1, rb=1):
    res = np.zeros(size)
    length = (rb - lb) / size
    for i in range(size):
        sub_lb = lb + length * i
        sub_rb = lb + length * (i + 1)
        res[i] = np.random.rand() * length + sub_lb
    return res

# %%
epochs = 5000
lr = 0.01

# alpha = np.random.uniform(low=0.005/np.pi, high=0.1/np.pi, size=1000)
# print(alpha)
alpha = np.random.uniform(low=-1, high=1, size=100)
beta = np.random.uniform(low=-1, high=1, size=100)
# alpha = -0.752
# beta = 0.932
# print("Alpha: {:.3f}, Beta: {:.3f}".format(alpha, beta))
# print(alpha)
# print(beta)
# loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse = train(epochs=epochs, lr=lr, i_size=0, b_size=2, f_size=100, zero_shot=False, alpha_list=alpha, beta_list=beta, low=-1, high=1, eqname='poisson')
loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse, val_losses, val_ood_losses = train(epochs=epochs, lr=lr, i_size=0, b_size=2, f_size=1, zero_shot=True, alpha_list=alpha, beta_list=beta, low=-1, high=1, eqname='poisson', load=False, load_data='models/poisson_zs_8000.data')
# loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse, val_losses, val_ood_losses= train(epochs=epochs, lr=lr, i_size=1, b_size=2, f_size=1, zero_shot=True, alpha_list=alpha, low=-1, high=1, eqname='burgers')
# loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse = train(epochs=epochs, lr=lr, i_size=100, b_size=100, f_size=10000, zero_shot=False, alpha_list=(0.01 / np.pi), low=-1, high=1, eqname='burgers')

# %%
# plt.plot(loss_i, label='loss_i')
plt.plot(loss_b, label='loss_b')
plt.plot(loss_f, label='loss_f')
plt.plot(loss, label='loss')
plt.yscale('log')
plt.legend()
plt.title('Zero-shot training losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# %%
# plt.plot(val_losses['loss_i'], label='loss_i')
plt.plot(val_losses['loss_b'], label='loss_b')
plt.plot(val_losses['loss_f'], label='loss_f')
plt.plot(val_losses['loss'], label='loss')
plt.yscale('log')
plt.legend()
plt.title('Zero-shot validation losses (in-distribution)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# %%
# plt.plot(val_losses['loss_i'], label='loss_i')
plt.plot(val_ood_losses['loss_b'], label='loss_b')
plt.plot(val_ood_losses['loss_f'], label='loss_f')
plt.plot(val_ood_losses['loss'], label='loss')
plt.yscale('log')
plt.legend()
plt.title('Zero-shot validation losses (out-of-distribution)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# %%
epochs = [5000 / len(val_loss) * i for i in range(1, len(val_loss) + 1)]
plt.plot(epochs, val_loss, label='in-distribution')
plt.plot(epochs, val_ood_loss, label='out-of-distribution')
plt.yscale('log')
plt.title("Validation metrics")
plt.xlabel('Epochs')
plt.ylabel('NRMSE')
plt.legend()
plt.show()

# %%
import pandas as pd

nrmse_df = pd.DataFrame(nrmse)
val_loss_df = pd.DataFrame(val_loss)
val_ood_loss_df = pd.DataFrame(val_ood_loss)
train_loss_df = pd.DataFrame({'loss_b': loss_b, 'loss_f': loss_f, 'loss': loss})

nrmse_df.to_csv('data/nrmse_burgers_zs.csv')
val_loss_df.to_csv('data/val_loss_burgers_zs.csv')
val_ood_loss_df.to_csv('data/val_ood_loss_burgers_zs.csv')
train_loss_df.to_csv('data/train_loss_burgers_zs.csv')

# %% [markdown]
# ## Results - Case 1

# %%
from maml import *

# %%
alpha = -1.26
beta = 1.48

# %%
loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse, val_losses, val_ood_losses = train(epochs=2000, lr=0.01, i_size=0, b_size=2, f_size=100, zero_shot=False, alpha_list=alpha, beta_list=beta, low=-1, high=1, eqname='poisson', load=False, load_data='models/poisson_zs_8000.data')

# %%
model3 = PINN(20, 5, dim=1, param_num=2, zero_shot=True)
model3.load_state_dict(torch.load('models/poisson_zs_2000_ref.data'))
model3.to(device)
model2 = PINN(20, 5, dim=1, param_num=2, zero_shot=True)
model2.load_state_dict(torch.load('models/model_used/maml_poisson_high1_5000.data'))
model2.to(device)

# %%
task = alpha, beta
maml = MAML(5, 0.01, 0.0005, 1,2,  1, -1, 1, eqname='poisson', zero_shot=True, load=False, modelpath='models/model_ref/burgers_zs_1000_ref.data')
phi, _, _, _, _, _, _ = maml._inner_loop(model2.state_dict(), task, train=True)
model_adapted = deepcopy(model2)
model_adapted.load_state_dict(phi)

# %%
test_x = np.linspace(-1, 1, num=100).reshape(-1, 1)
test_alpha = np.full((100, 1), alpha)
test_beta = np.full((100, 1), beta)

X = test_x

Y = np.sin(test_alpha * X) + np.cos(test_beta * X) + 0.1 * X
test_in = np.hstack((test_x, test_alpha, test_beta))
test_in_ = test_x
test_u_ = model(torch.Tensor(test_in_).to(device))
test_u = model3(torch.Tensor(test_in).to(device))
# test_in = test_x
test_u_2 = model2(torch.Tensor(test_in).to(device))
test_u_3 = model_adapted(torch.Tensor(test_in).to(device))

# %%
C_ = test_u_.cpu().detach().numpy()
C = test_u.cpu().detach().numpy()
C2 = test_u_2.cpu().detach().numpy()
C3 = test_u_3.cpu().detach().numpy()
plt.figure(figsize=(10, 8))
plt.plot(X, Y, 'k', label='truth')
plt.plot(X, C_, 'r--', label='PINN')
plt.plot(X, C, 'b--', label='zero-shot')
plt.plot(X, C2, 'g--', label='MAML')
plt.plot(X, C3, 'y--', label='adapted MAML')
plt.xlabel('x')
plt.ylabel('u')
plt.title('Solutions (out-of-distribution)')
plt.legend()

# %%
def compute_nrmse(C, Y):
    return np.sqrt(np.sum((C-Y)**2)/np.sum(C**2))

# %%
compute_nrmse(C_, Y)

# %%
nrmse_test_zs = []
nrmse_test_maml = []
nrmse_test_maml_adapted = []
nrmse_test_pinn = []

alpha_val = np.hstack((np.random.uniform(low=-1.5, high=-1, size=5), np.random.uniform(low=1, high=1.5, size=5)))
beta_val = np.hstack((np.random.uniform(low=-1.5, high=-1, size=5), np.random.uniform(low=1, high=1.5, size=5)))

for alpha, beta in zip(alpha_val, beta_val):
    loss_i, loss_b, loss_f, loss, model_, val_loss, val_ood_loss, nrmse, _, _ = train(epochs=1000, lr=0.01, i_size=0, b_size=2, f_size=100, zero_shot=False, alpha_list=alpha, beta_list=beta, low=-1, high=1, eqname='poisson')
    test_x = np.linspace(-1, 1, num=100).reshape(-1, 1)
    test_alpha = np.full((100, 1), alpha)
    test_beta = np.full((100, 1), beta)
    X = test_x
    Y = np.sin(test_alpha * X) + np.cos(test_beta * X) + 0.1 * X
    test_in = np.hstack((test_x, test_alpha, test_beta))
    test_u_ = model_(torch.Tensor(test_x).to(device))
    test_u = model3(torch.Tensor(test_in).to(device))
    test_u_2 = model2(torch.Tensor(test_in).to(device))
    test_u_3 = model_adapted(torch.Tensor(test_in).to(device))
    C_ = test_u_.cpu().detach().numpy()
    C = test_u.cpu().detach().numpy()
    C2 = test_u_2.cpu().detach().numpy()
    C3 = test_u_3.cpu().detach().numpy()
    nrmse_test_pinn.append(compute_nrmse(C_, Y))
    nrmse_test_zs.append(compute_nrmse(C, Y))
    nrmse_test_maml.append(compute_nrmse(C2, Y))
    nrmse_test_maml_adapted.append(compute_nrmse(C3, Y))
   
mean_nrmse_pinn = np.mean(np.array(nrmse_test_pinn))                    
mean_nrmse_zs = np.mean(np.array(nrmse_test_zs))
mean_nrmse_maml = np.mean(np.array(nrmse_test_maml))
mean_nrmse_adapt_maml = np.mean(np.array(nrmse_test_maml_adapted))

std_nrmse_pinn = np.std(np.array(nrmse_test_pinn))                    
std_nrmse_zs = np.std(np.array(nrmse_test_zs))
std_nrmse_maml = np.std(np.array(nrmse_test_maml))
std_nrmse_adapt_maml = np.std(np.array(nrmse_test_maml_adapted))
    
high_nrmse_pinn = mean_nrmse_pinn + 1.96 * std_nrmse_pinn                    
high_nrmse_zs = mean_nrmse_zs + 1.96 * std_nrmse_zs
high_nrmse_maml = mean_nrmse_maml + 1.96 * std_nrmse_maml
high_nrmse_adapt_maml = mean_nrmse_adapt_maml + 1.96 * std_nrmse_adapt_maml

low_nrmse_pinn = mean_nrmse_pinn - 1.96 * std_nrmse_pinn                    
low_nrmse_zs = mean_nrmse_zs - 1.96 * std_nrmse_zs
low_nrmse_maml = mean_nrmse_maml - 1.96 * std_nrmse_maml
low_nrmse_adapt_maml = mean_nrmse_adapt_maml - 1.96 * std_nrmse_adapt_maml

# %%
x = np.arange(4)
methods = ['PINN', 'zero-shot', 'MAML', 'adapted MAML']
values = [mean_nrmse_pinn, mean_nrmse_zs, mean_nrmse_maml, mean_nrmse_adapt_maml]
yerr = [(high_nrmse_pinn - low_nrmse_pinn) / np.sqrt(10), (high_nrmse_zs - low_nrmse_zs) / np.sqrt(10), (high_nrmse_maml - low_nrmse_maml) / np.sqrt(10), (high_nrmse_adapt_maml - low_nrmse_adapt_maml)/ np.sqrt(10)] 
colors = ['r', 'b', 'g', 'y']

plt.bar(x, values, color=colors, yerr=yerr, capsize=10)
plt.xticks(x, methods)
plt.yscale('log')
plt.ylabel('NRMSE')
plt.title('NRMSEs (out-of-distribution)')

plt.show()

# %%
nrmse_test_zs

# %% [markdown]
# ## Results - Case 2

# %%
model3 = PINN(20, 5, dim=1, param_num=2, zero_shot=True)
model3.load_state_dict(torch.load('models/poisson_zs_1000_ref_case2.data'))
model3.to(device)
model2 = PINN(20, 5, dim=1, param_num=2, zero_shot=True)
model2.load_state_dict(torch.load('models/model_used/maml_poisson_high10_5000.data'))
model2.to(device)

# %%
from maml import *

# %%
alpha = -0.752
beta = 0.932
alpha = -1.260
beta = 1.480

# %%
task = alpha, beta
maml = MAML(5, 0.01, 0.0005, 1,2,  1, -10, 10, eqname='poisson', zero_shot=True, load=False, modelpath='models/model_ref/burgers_zs_1000_ref.data')
phi, _, _, _, _, _, _ = maml._inner_loop(model2.state_dict(), task, train=True)
model_adapted = deepcopy(model2)
model_adapted.load_state_dict(phi)

# %%
loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse, val_losses, val_ood_losses = train(epochs=1000, lr=0.01, i_size=0, b_size=2, f_size=100, zero_shot=False, alpha_list=alpha, beta_list=beta, low=-10, high=10, eqname='poisson')

# %%
test_x = np.linspace(-10, 10, num=100).reshape(-1, 1)
# test_alpha = np.full((100, 1), alpha[2])
# test_beta = np.full((100, 1), beta[2])
alpha = -0.752
beta = 0.932
alpha = -1.260
beta = 1.480
test_alpha = np.full((100, 1), alpha)
test_beta = np.full((100, 1), beta)
test_in = np.hstack((test_x, test_alpha, test_beta))
# test_in = test_x
test_u_ = model(torch.Tensor(test_x).to(device))
test_u = model3(torch.Tensor(test_in).to(device))
X = test_x

Y = np.sin(test_alpha * X) + np.cos(test_beta * X) + 0.1 * X

# %%
test_x = np.linspace(-10, 10, num=100).reshape(-1, 1)
test_in = np.hstack((test_x, test_alpha, test_beta))
# test_in = test_x
test_u = model3(torch.Tensor(test_in).to(device))
test_u_2 = model2(torch.Tensor(test_in).to(device))
test_u_3 = model_adapted(torch.Tensor(test_in).to(device))

# %%
C_ = test_u_.cpu().detach().numpy()
C = test_u.cpu().detach().numpy()
C2 = test_u_2.cpu().detach().numpy()
C3 = test_u_3.cpu().detach().numpy()
plt.figure(figsize=(10, 8))
plt.plot(X, C_, 'r--', label='PINN')
plt.plot(X, C, 'b--', label='zero-shot')
plt.plot(X, Y, 'k', label='truth')
plt.plot(X, C2, 'g--', label='MAML')
plt.plot(X, C3, 'y--', label='adapted MAML')
plt.legend()
plt.title('Solutions (out-of-distribution)')
# plt.colorbar()

# %%
np.sqrt(np.sum( (Y-C) ** 2) / np.sum( C ** 2 ))

# %%
nrmse_test_zs = []
nrmse_test_maml = []
nrmse_test_maml_adapted = []
nrmse_test_pinn = []

# alpha_val = np.random.uniform(low=-1, high=1, size=10)
# beta_val = np.random.uniform(low=-1, high=1, size=10)
alpha_val = np.hstack((np.random.uniform(low=-1.5, high=-1, size=5), np.random.uniform(low=1, high=1.5, size=5)))
beta_val = np.hstack((np.random.uniform(low=-1.5, high=-1, size=5), np.random.uniform(low=1, high=1.5, size=5)))

for alpha, beta in zip(alpha_val, beta_val):
    loss_i, loss_b, loss_f, loss, model_, val_loss, val_ood_loss, nrmse, _, _ = train(epochs=1000, lr=0.01, i_size=0, b_size=2, f_size=100, zero_shot=False, alpha_list=alpha, beta_list=beta, low=-10, high=10, eqname='poisson')
    test_x = np.linspace(-1, 1, num=100).reshape(-1, 1)
    test_alpha = np.full((100, 1), alpha)
    test_beta = np.full((100, 1), beta)
    X = test_x
    Y = np.sin(test_alpha * X) + np.cos(test_beta * X) + 0.1 * X
    test_in = np.hstack((test_x, test_alpha, test_beta))
    test_u_ = model_(torch.Tensor(test_x).to(device))
    test_u = model3(torch.Tensor(test_in).to(device))
    test_u_2 = model2(torch.Tensor(test_in).to(device))
    test_u_3 = model_adapted(torch.Tensor(test_in).to(device))
    C_ = test_u_.cpu().detach().numpy()
    C = test_u.cpu().detach().numpy()
    C2 = test_u_2.cpu().detach().numpy()
    C3 = test_u_3.cpu().detach().numpy()
    nrmse_test_pinn.append(compute_nrmse(C_, Y))
    nrmse_test_zs.append(compute_nrmse(C, Y))
    nrmse_test_maml.append(compute_nrmse(C2, Y))
    nrmse_test_maml_adapted.append(compute_nrmse(C3, Y))
    
mean_nrmse_pinn = np.mean(np.array(nrmse_test_pinn))                    
mean_nrmse_zs = np.mean(np.array(nrmse_test_zs))
mean_nrmse_maml = np.mean(np.array(nrmse_test_maml))
mean_nrmse_adapt_maml = np.mean(np.array(nrmse_test_maml_adapted))

std_nrmse_pinn = np.std(np.array(nrmse_test_pinn))                    
std_nrmse_zs = np.std(np.array(nrmse_test_zs))
std_nrmse_maml = np.std(np.array(nrmse_test_maml))
std_nrmse_adapt_maml = np.std(np.array(nrmse_test_maml_adapted))
    
high_nrmse_pinn = mean_nrmse_pinn + 1.96 * std_nrmse_pinn                    
high_nrmse_zs = mean_nrmse_zs + 1.96 * std_nrmse_zs
high_nrmse_maml = mean_nrmse_maml + 1.96 * std_nrmse_maml
high_nrmse_adapt_maml = mean_nrmse_adapt_maml + 1.96 * std_nrmse_adapt_maml

low_nrmse_pinn = mean_nrmse_pinn - 1.96 * std_nrmse_pinn                    
low_nrmse_zs = mean_nrmse_zs - 1.96 * std_nrmse_zs
low_nrmse_maml = mean_nrmse_maml - 1.96 * std_nrmse_maml
low_nrmse_adapt_maml = mean_nrmse_adapt_maml - 1.96 * std_nrmse_adapt_maml

# %%
x = np.arange(4)
methods = ['PINN', 'zero-shot', 'MAML', 'adapted MAML']
values = [mean_nrmse_pinn, mean_nrmse_zs, mean_nrmse_maml, mean_nrmse_adapt_maml]
yerr = [(high_nrmse_pinn - low_nrmse_pinn) / np.sqrt(10), (high_nrmse_zs - low_nrmse_zs) / np.sqrt(10), (high_nrmse_maml - low_nrmse_maml) / np.sqrt(10), (high_nrmse_adapt_maml - low_nrmse_adapt_maml)/ np.sqrt(10)] 
colors = ['r', 'b', 'g', 'y']

plt.bar(x, values, color=colors, yerr=yerr, capsize=10)
plt.xticks(x, methods)
plt.yscale('log')
plt.ylabel('NRMSE')
plt.title('NRMSEs (out-of-distribution)')

plt.show()

# %% [markdown]
# ## Result - Case 3

# %%
from burgers import *

# %%
model = PINN(20, 8, dim=2, param_num=1, zero_shot=True)
model.load_state_dict(torch.load('models/burgers_zs_4000.data'))
model.to(device)
# Out:
# PINN(
#   (module1): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Linear(in_features=20, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=20, bias=True)
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Linear(in_features=20, out_features=20, bias=True)
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
model_maml = PINN(20, 8, dim=2, param_num=1, zero_shot=True)
model_maml.load_state_dict(torch.load('models/model_used/maml_burgers_from_scratch_5000_ref.data'))
model_maml.to(device)
# Out:
# PINN(
#   (module1): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Linear(in_features=20, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=20, bias=True)
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Linear(in_features=20, out_features=20, bias=True)
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
vtn = 101
vxn = 101
nu = 0.01 / np.pi
vx = np.linspace(-1, 1, vxn)
vt = np.linspace(0, 1, vtn)
x, t = np.meshgrid(vx, vt)
x = x.reshape(-1, 1)
t = t.reshape(-1, 1)
alpha = np.full((x.shape), nu)
pred = model(torch.Tensor(np.hstack((x, t, alpha))).to(device)).detach().cpu().numpy()
truth = burgers_viscous_time_exact1(nu, vxn, vx, vtn, vt).T

# %%
torch.save(model.state_dict(), 'models/model_used/burgers_zs_4000_ref.data')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x, t, c=pred, cmap='seismic')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Zero-shot')
plt.colorbar()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x, t, c=truth, cmap='seismic')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Truth')
plt.colorbar()

# %%
from maml import *

# %%
maml = MAML(5, 0.01, 0.0005, 1,2, 1, -1, 1, eqname='burgers', zero_shot=True, load=False, modelpath='models/model_ref/burgers_zs_1000_ref.data')
phi, _, inner_loss_i, inner_loss_b, inner_loss_f, inner_loss, nrmse_batch = maml._inner_loop(model_maml.state_dict(), nu, train=False)
model_adapted = deepcopy(model)
model_adapted.load_state_dict(phi)
pred_maml = model_maml(torch.Tensor(np.hstack((x, t, alpha))).to(device)).detach().cpu().numpy()
pred_maml_adapted = model_adapted(torch.Tensor(np.hstack((x, t, alpha))).to(device)).detach().cpu().numpy()
# Out:
# Initializing MAML-PINN model
# Current device:  cuda
# cuda
# Zero shot mode is True
# Finished initialization of MAML-PINN model
# Trained model will be saved by None

# %%
nrmse_batch

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x, t, c=pred_maml, cmap='seismic')
plt.xlabel('x')
plt.ylabel('t')
plt.title('MAML')
plt.colorbar()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x, t, c=pred_maml_adapted, cmap='seismic')
plt.xlabel('x')
plt.ylabel('t')
plt.title('MAML-adapted')
plt.colorbar()

# %%
loss_i, loss_b, loss_f, loss, model_pinn, val_loss, val_ood_loss, nrmse, val_losses, val_ood_losses = train(epochs=5000, lr=0.01, i_size=100, b_size=100, f_size=1000, zero_shot=False, alpha_list=0.01/np.pi, low=-1, high=1, eqname='burgers')
# Out:
# Current device: cuda
# Data generation completed
# Epoch 100 | Loss_I: 0.1646 | Loss_B: 0.0429 | Loss_F: 0.0203
# Epoch 200 | Loss_I: 0.1113 | Loss_B: 0.0256 | Loss_F: 0.0272
# Epoch 300 | Loss_I: 0.0897 | Loss_B: 0.0198 | Loss_F: 0.0287
# Epoch 400 | Loss_I: 0.0807 | Loss_B: 0.0175 | Loss_F: 0.0292
# Epoch 500 | Loss_I: 0.0718 | Loss_B: 0.0154 | Loss_F: 0.0287
# Epoch 600 | Loss_I: 0.0656 | Loss_B: 0.0137 | Loss_F: 0.0287
# Epoch 700 | Loss_I: 0.0691 | Loss_B: 0.0134 | Loss_F: 0.0305
# Epoch 800 | Loss_I: 0.0686 | Loss_B: 0.0128 | Loss_F: 0.0312
# Epoch 900 | Loss_I: 0.0656 | Loss_B: 0.0116 | Loss_F: 0.0304
# Epoch 1000 | Loss_I: 0.0703 | Loss_B: 0.0134 | Loss_F: 0.0315
# Epoch 1100 | Loss_I: 0.0743 | Loss_B: 0.0139 | Loss_F: 0.0332
# Epoch 1200 | Loss_I: 0.0754 | Loss_B: 0.0132 | Loss_F: 0.0341
# Epoch 1300 | Loss_I: 0.0735 | Loss_B: 0.0125 | Loss_F: 0.0341
# Epoch 1400 | Loss_I: 0.0709 | Loss_B: 0.0117 | Loss_F: 0.0339
# Epoch 1500 | Loss_I: 0.0770 | Loss_B: 0.0115 | Loss_F: 0.0344
# Epoch 1600 | Loss_I: 0.0752 | Loss_B: 0.0109 | Loss_F: 0.0342
# Epoch 1700 | Loss_I: 0.0742 | Loss_B: 0.0106 | Loss_F: 0.0343
# Epoch 1800 | Loss_I: 0.0723 | Loss_B: 0.0101 | Loss_F: 0.0341
# Epoch 1900 | Loss_I: 0.0693 | Loss_B: 0.0096 | Loss_F: 0.0331
# Epoch 2000 | Loss_I: 0.0834 | Loss_B: 0.0102 | Loss_F: 0.0342
# Epoch 2100 | Loss_I: 0.0849 | Loss_B: 0.0114 | Loss_F: 0.0332
# Epoch 2200 | Loss_I: 0.0858 | Loss_B: 0.0128 | Loss_F: 0.0320
# Epoch 2300 | Loss_I: 0.0867 | Loss_B: 0.0142 | Loss_F: 0.0309
# Epoch 2400 | Loss_I: 0.0874 | Loss_B: 0.0154 | Loss_F: 0.0299
# Epoch 2500 | Loss_I: 0.0880 | Loss_B: 0.0166 | Loss_F: 0.0288
# Epoch 2600 | Loss_I: 0.0885 | Loss_B: 0.0177 | Loss_F: 0.0279
# Epoch 2700 | Loss_I: 0.0890 | Loss_B: 0.0188 | Loss_F: 0.0270
# Epoch 2800 | Loss_I: 0.0895 | Loss_B: 0.0197 | Loss_F: 0.0262
# Epoch 2900 | Loss_I: 0.0900 | Loss_B: 0.0205 | Loss_F: 0.0254
# Epoch 3000 | Loss_I: 0.0904 | Loss_B: 0.0213 | Loss_F: 0.0248
# Epoch 3100 | Loss_I: 0.0908 | Loss_B: 0.0222 | Loss_F: 0.0243
# Epoch 3200 | Loss_I: 0.0911 | Loss_B: 0.0229 | Loss_F: 0.0238
# Epoch 3300 | Loss_I: 0.0927 | Loss_B: 0.0236 | Loss_F: 0.0236
# Epoch 3400 | Loss_I: 0.0931 | Loss_B: 0.0243 | Loss_F: 0.0234
# Epoch 3500 | Loss_I: 0.0934 | Loss_B: 0.0250 | Loss_F: 0.0230
# Epoch 3600 | Loss_I: 0.0941 | Loss_B: 0.0256 | Loss_F: 0.0227
# Epoch 3700 | Loss_I: 0.0937 | Loss_B: 0.0252 | Loss_F: 0.0229
# Epoch 3800 | Loss_I: 0.0925 | Loss_B: 0.0245 | Loss_F: 0.0231
# Epoch 3900 | Loss_I: 0.0910 | Loss_B: 0.0240 | Loss_F: 0.0232
# Epoch 4000 | Loss_I: 0.0943 | Loss_B: 0.0242 | Loss_F: 0.0234
# Epoch 4100 | Loss_I: 0.0951 | Loss_B: 0.0244 | Loss_F: 0.0231
# Epoch 4200 | Loss_I: 0.0955 | Loss_B: 0.0247 | Loss_F: 0.0228
# Epoch 4300 | Loss_I: 0.0957 | Loss_B: 0.0250 | Loss_F: 0.0224
# Epoch 4400 | Loss_I: 0.0960 | Loss_B: 0.0248 | Loss_F: 0.0227
# Epoch 4500 | Loss_I: 0.0962 | Loss_B: 0.0245 | Loss_F: 0.0230
# Epoch 4600 | Loss_I: 0.0956 | Loss_B: 0.0240 | Loss_F: 0.0234
# Epoch 4700 | Loss_I: 0.0945 | Loss_B: 0.0236 | Loss_F: 0.0236
# Epoch 4800 | Loss_I: 0.0932 | Loss_B: 0.0231 | Loss_F: 0.0237
# Epoch 4900 | Loss_I: 0.0920 | Loss_B: 0.0227 | Loss_F: 0.0238
# Epoch 5000 | Loss_I: 0.0921 | Loss_B: 0.0224 | Loss_F: 0.0239

# %%
pred_pinn = model_pinn(torch.Tensor(np.hstack((x, t))).to(device)).detach().cpu().numpy()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x, t, c=pred_pinn, cmap='seismic')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Single PINN')
plt.colorbar()

# %%
idx = 25
print(vt[idx])
x_025 = np.linspace(-1, 1, 101).reshape(-1, 1)
t_025 = np.full((x_025.shape), idx / 100)

pred_ = model(torch.Tensor(np.hstack((x_025, t_025, np.full((x_025.shape), nu)))).to(device)).detach().cpu().numpy()
pred_maml_ = model_maml(torch.Tensor(np.hstack((x_025, t_025, np.full((x_025.shape), nu)))).to(device)).detach().cpu().numpy()
pred_pinn_ = model_pinn(torch.Tensor(np.hstack((x_025, t_025))).to(device)).detach().cpu().numpy()
task = 0.01 / np.pi
# test_in = np.hstack((x, t, alpha))
test_in_t = np.hstack((x_025, t_025, np.full((x_025.shape), task)))

model_adapted = deepcopy(model)
model_adapted.load_state_dict(phi)
# Y2 = model_adapted(torch.Tensor(test_in).to(device)).detach().cpu().numpy()
Y2_t = model_adapted(torch.Tensor(test_in_t).to(device)).detach().cpu().numpy()
# Out:
# 0.25

# %%
plt.plot(truth[idx, :], 'k', linewidth=3, label='truth')
plt.plot(pred_, 'b--', linewidth=3, label='zero-shot')
plt.plot(pred_maml_, 'g--', linewidth=3, label='MAML')
plt.plot(pred_pinn_, 'r--', linewidth=3, label='PINN')
plt.plot(Y2_t, 'y--', linewidth=3, label='MAML-adapted')
plt.legend()
plt.title('t={}'.format(vt[idx]))
# Out:
# Text(0.5, 1.0, 't=0.25')

# %%
np.sqrt(np.sum((pred-truth.reshape(-1, 1)) ** 2) / np.sum(pred ** 2))

# %%
np.mean(np.abs(pred-truth.reshape(-1, 1)))

# %%
plt.scatter(x, t, c=((pred.reshape(101, 101) - truth) ** 2).reshape(-1, 1), cmap='seismic')
plt.colorbar()

# %%
def compute_nrmse(C, Y):
    return np.sqrt(np.sum((C-Y)**2)/np.sum(C**2))

# %%
nrmse_test_zs = []
nrmse_test_maml = []
nrmse_test_maml_adapted = []
nrmse_test_pinn = []

alpha_val = np.random.uniform(low=0.005/np.pi, high=0.1/np.pi, size=5)
# beta_val = np.random.uniform(low=-1, high=1, size=10)
alpha_val = np.hstack((np.random.uniform(low=0.001/np.pi, high=0.005/np.pi, size=2), np.random.uniform(low=0.1/np.pi, high=0.2/np.pi, size=3)))
# beta_val = np.hstack((np.random.uniform(low=-1.5, high=-1, size=5), np.random.uniform(low=1, high=1.5, size=5)))

for alpha in alpha_val:
    loss_i, loss_b, loss_f, loss, model_, val_loss, val_ood_loss, nrmse, _, _ = train(epochs=5000, lr=0.01, i_size=100, b_size=100, f_size=1000, zero_shot=False, alpha_list=alpha, beta_list=None, low=-1, high=1, eqname='burgers')
    vtn = 21
    vxn = 21
    test_alpha = np.full((vtn * vxn, 1), alpha)
    nu = 0.2 / np.pi
    vx = np.linspace(-1, 1, vxn)
    vt = np.linspace(0, 1, vtn)
    x, t = np.meshgrid(vx, vt)
    x = x.reshape(-1, 1)
    t = t.reshape(-1, 1)
    truth = burgers_viscous_time_exact1(nu, vxn, vx, vtn, vt).T
    Y = truth.reshape(-1, 1)
    test_in = np.hstack((x, t, test_alpha))
    test_x = np.hstack((x, t))
    test_u_ = model_(torch.Tensor(test_x).to(device))
    test_u = model(torch.Tensor(test_in).to(device))
    test_u_2 = model_maml(torch.Tensor(test_in).to(device))
    test_u_3 = model_adapted(torch.Tensor(test_in).to(device))
    C_ = test_u_.cpu().detach().numpy()
    C = test_u.cpu().detach().numpy()
    C2 = test_u_2.cpu().detach().numpy()
    C3 = test_u_3.cpu().detach().numpy()
    nrmse_test_pinn.append(compute_nrmse(C_, Y))
    nrmse_test_zs.append(compute_nrmse(C, Y))
    nrmse_test_maml.append(compute_nrmse(C2, Y))
    nrmse_test_maml_adapted.append(compute_nrmse(C3, Y))
    
mean_nrmse_pinn = np.mean(np.array(nrmse_test_pinn))                    
mean_nrmse_zs = np.mean(np.array(nrmse_test_zs))
mean_nrmse_maml = np.mean(np.array(nrmse_test_maml))
mean_nrmse_adapt_maml = np.mean(np.array(nrmse_test_maml_adapted))

std_nrmse_pinn = np.std(np.array(nrmse_test_pinn))                    
std_nrmse_zs = np.std(np.array(nrmse_test_zs))
std_nrmse_maml = np.std(np.array(nrmse_test_maml))
std_nrmse_adapt_maml = np.std(np.array(nrmse_test_maml_adapted))
    
high_nrmse_pinn = mean_nrmse_pinn + 1.96 * std_nrmse_pinn                    
high_nrmse_zs = mean_nrmse_zs + 1.96 * std_nrmse_zs
high_nrmse_maml = mean_nrmse_maml + 1.96 * std_nrmse_maml
high_nrmse_adapt_maml = mean_nrmse_adapt_maml + 1.96 * std_nrmse_adapt_maml

low_nrmse_pinn = mean_nrmse_pinn - 1.96 * std_nrmse_pinn                    
low_nrmse_zs = mean_nrmse_zs - 1.96 * std_nrmse_zs
low_nrmse_maml = mean_nrmse_maml - 1.96 * std_nrmse_maml
low_nrmse_adapt_maml = mean_nrmse_adapt_maml - 1.96 * std_nrmse_adapt_maml
# Out:
# Current device: cuda
# Data generation completed
# Epoch 100 | Loss_I: 0.1503 | Loss_B: 0.0292 | Loss_F: 0.0310
# Epoch 200 | Loss_I: 0.1033 | Loss_B: 0.0157 | Loss_F: 0.0336
# Epoch 300 | Loss_I: 0.1067 | Loss_B: 0.0158 | Loss_F: 0.0380
# Epoch 400 | Loss_I: 0.0958 | Loss_B: 0.0124 | Loss_F: 0.0392
# Epoch 500 | Loss_I: 0.0906 | Loss_B: 0.0105 | Loss_F: 0.0398
# Epoch 600 | Loss_I: 0.0873 | Loss_B: 0.0093 | Loss_F: 0.0405
# Epoch 700 | Loss_I: 0.0860 | Loss_B: 0.0085 | Loss_F: 0.0409
# Epoch 800 | Loss_I: 0.1006 | Loss_B: 0.0114 | Loss_F: 0.0401
# Epoch 900 | Loss_I: 0.0998 | Loss_B: 0.0116 | Loss_F: 0.0399
# Epoch 1000 | Loss_I: 0.0958 | Loss_B: 0.0106 | Loss_F: 0.0396
# Epoch 1100 | Loss_I: 0.0928 | Loss_B: 0.0099 | Loss_F: 0.0395
# Epoch 1200 | Loss_I: 0.0897 | Loss_B: 0.0091 | Loss_F: 0.0391
# Epoch 1300 | Loss_I: 0.0969 | Loss_B: 0.0102 | Loss_F: 0.0389
# Epoch 1400 | Loss_I: 0.0950 | Loss_B: 0.0097 | Loss_F: 0.0394
# Epoch 1500 | Loss_I: 0.0967 | Loss_B: 0.0096 | Loss_F: 0.0401
# Epoch 1600 | Loss_I: 0.0946 | Loss_B: 0.0091 | Loss_F: 0.0398
# Epoch 1700 | Loss_I: 0.0934 | Loss_B: 0.0087 | Loss_F: 0.0402
# Epoch 1800 | Loss_I: 0.0913 | Loss_B: 0.0083 | Loss_F: 0.0401
# Epoch 1900 | Loss_I: 0.0895 | Loss_B: 0.0079 | Loss_F: 0.0401
# Epoch 2000 | Loss_I: 0.0881 | Loss_B: 0.0076 | Loss_F: 0.0401
# Epoch 2100 | Loss_I: 0.0861 | Loss_B: 0.0073 | Loss_F: 0.0398
# Epoch 2200 | Loss_I: 0.0884 | Loss_B: 0.0083 | Loss_F: 0.0403
# Epoch 2300 | Loss_I: 0.0868 | Loss_B: 0.0080 | Loss_F: 0.0405
# Epoch 2400 | Loss_I: 0.0861 | Loss_B: 0.0081 | Loss_F: 0.0408
# Epoch 2500 | Loss_I: 0.0844 | Loss_B: 0.0077 | Loss_F: 0.0407
# Epoch 2600 | Loss_I: 0.0881 | Loss_B: 0.0083 | Loss_F: 0.0415
# Epoch 2700 | Loss_I: 0.0958 | Loss_B: 0.0088 | Loss_F: 0.0411
# Epoch 2800 | Loss_I: 0.1006 | Loss_B: 0.0099 | Loss_F: 0.0410
# Epoch 2900 | Loss_I: 0.1018 | Loss_B: 0.0119 | Loss_F: 0.0406
# Epoch 3000 | Loss_I: 0.1024 | Loss_B: 0.0130 | Loss_F: 0.0400
# Epoch 3100 | Loss_I: 0.1026 | Loss_B: 0.0141 | Loss_F: 0.0392
# Epoch 3200 | Loss_I: 0.1027 | Loss_B: 0.0151 | Loss_F: 0.0385
# Epoch 3300 | Loss_I: 0.1082 | Loss_B: 0.0158 | Loss_F: 0.0379
# Epoch 3400 | Loss_I: 0.1105 | Loss_B: 0.0176 | Loss_F: 0.0371
# Epoch 3500 | Loss_I: 0.1113 | Loss_B: 0.0183 | Loss_F: 0.0366
# Epoch 3600 | Loss_I: 0.1116 | Loss_B: 0.0190 | Loss_F: 0.0360
# Epoch 3700 | Loss_I: 0.1120 | Loss_B: 0.0196 | Loss_F: 0.0356
# Epoch 3800 | Loss_I: 0.1115 | Loss_B: 0.0200 | Loss_F: 0.0353
# Epoch 3900 | Loss_I: 0.1099 | Loss_B: 0.0199 | Loss_F: 0.0353
# Epoch 4000 | Loss_I: 0.1078 | Loss_B: 0.0195 | Loss_F: 0.0352
# Epoch 4100 | Loss_I: 0.1056 | Loss_B: 0.0191 | Loss_F: 0.0347
# Epoch 4200 | Loss_I: 0.1034 | Loss_B: 0.0187 | Loss_F: 0.0342
# Epoch 4300 | Loss_I: 0.1013 | Loss_B: 0.0183 | Loss_F: 0.0337
# Epoch 4400 | Loss_I: 0.0993 | Loss_B: 0.0179 | Loss_F: 0.0331
# Epoch 4500 | Loss_I: 0.0974 | Loss_B: 0.0175 | Loss_F: 0.0326
# Epoch 4600 | Loss_I: 0.0961 | Loss_B: 0.0178 | Loss_F: 0.0412
# Epoch 4700 | Loss_I: 0.1056 | Loss_B: 0.0196 | Loss_F: 0.0404
# Epoch 4800 | Loss_I: 0.1108 | Loss_B: 0.0198 | Loss_F: 0.0396
# Epoch 4900 | Loss_I: 0.1144 | Loss_B: 0.0199 | Loss_F: 0.0392
# Epoch 5000 | Loss_I: 0.1154 | Loss_B: 0.0199 | Loss_F: 0.0390
# Current device: cuda
# Data generation completed
# Epoch 100 | Loss_I: 0.1689 | Loss_B: 0.0424 | Loss_F: 0.0241
# Epoch 200 | Loss_I: 0.1130 | Loss_B: 0.0229 | Loss_F: 0.0300
# Epoch 300 | Loss_I: 0.0924 | Loss_B: 0.0156 | Loss_F: 0.0295
# Epoch 400 | Loss_I: 0.0818 | Loss_B: 0.0119 | Loss_F: 0.0283
# Epoch 500 | Loss_I: 0.0762 | Loss_B: 0.0097 | Loss_F: 0.0286
# Epoch 600 | Loss_I: 0.0757 | Loss_B: 0.0087 | Loss_F: 0.0305
# Epoch 700 | Loss_I: 0.0724 | Loss_B: 0.0075 | Loss_F: 0.0311
# Epoch 800 | Loss_I: 0.0692 | Loss_B: 0.0067 | Loss_F: 0.0310
# Epoch 900 | Loss_I: 0.0755 | Loss_B: 0.0074 | Loss_F: 0.0315
# Epoch 1000 | Loss_I: 0.0810 | Loss_B: 0.0082 | Loss_F: 0.0323
# Epoch 1100 | Loss_I: 0.0783 | Loss_B: 0.0076 | Loss_F: 0.0320
# Epoch 1200 | Loss_I: 0.0754 | Loss_B: 0.0071 | Loss_F: 0.0313
# Epoch 1300 | Loss_I: 0.0764 | Loss_B: 0.0074 | Loss_F: 0.0322
# Epoch 1400 | Loss_I: 0.0744 | Loss_B: 0.0072 | Loss_F: 0.0320
# Epoch 1500 | Loss_I: 0.0711 | Loss_B: 0.0068 | Loss_F: 0.0309
# Epoch 1600 | Loss_I: 0.0672 | Loss_B: 0.0064 | Loss_F: 0.0294
# Epoch 1700 | Loss_I: 0.0633 | Loss_B: 0.0060 | Loss_F: 0.0279
# Epoch 1800 | Loss_I: 0.0598 | Loss_B: 0.0057 | Loss_F: 0.0264
# Epoch 1900 | Loss_I: 0.0567 | Loss_B: 0.0054 | Loss_F: 0.0250
# Epoch 2000 | Loss_I: 0.0539 | Loss_B: 0.0051 | Loss_F: 0.0238
# Epoch 2100 | Loss_I: 0.0513 | Loss_B: 0.0049 | Loss_F: 0.0227
# Epoch 2200 | Loss_I: 0.0490 | Loss_B: 0.0047 | Loss_F: 0.0217
# Epoch 2300 | Loss_I: 0.0469 | Loss_B: 0.0045 | Loss_F: 0.0208
# Epoch 2400 | Loss_I: 0.0449 | Loss_B: 0.0043 | Loss_F: 0.0199
# Epoch 2500 | Loss_I: 0.0431 | Loss_B: 0.0041 | Loss_F: 0.0191
# Epoch 2600 | Loss_I: 0.0415 | Loss_B: 0.0040 | Loss_F: 0.0184
# Epoch 2700 | Loss_I: 0.0400 | Loss_B: 0.0038 | Loss_F: 0.0177
# Epoch 2800 | Loss_I: 0.0385 | Loss_B: 0.0037 | Loss_F: 0.0171
# Epoch 2900 | Loss_I: 0.0372 | Loss_B: 0.0036 | Loss_F: 0.0165
# Epoch 3000 | Loss_I: 0.0360 | Loss_B: 0.0035 | Loss_F: 0.0160
# Epoch 3100 | Loss_I: 0.0348 | Loss_B: 0.0033 | Loss_F: 0.0155
# Epoch 3200 | Loss_I: 0.0337 | Loss_B: 0.0032 | Loss_F: 0.0150
# Epoch 3300 | Loss_I: 0.0327 | Loss_B: 0.0031 | Loss_F: 0.0146
# Epoch 3400 | Loss_I: 0.0318 | Loss_B: 0.0031 | Loss_F: 0.0141
# Epoch 3500 | Loss_I: 0.0308 | Loss_B: 0.0030 | Loss_F: 0.0138
# Epoch 3600 | Loss_I: 0.0300 | Loss_B: 0.0029 | Loss_F: 0.0134
# Epoch 3700 | Loss_I: 0.0292 | Loss_B: 0.0028 | Loss_F: 0.0130
# Epoch 3800 | Loss_I: 0.0284 | Loss_B: 0.0027 | Loss_F: 0.0127
# Epoch 3900 | Loss_I: 0.0277 | Loss_B: 0.0027 | Loss_F: 0.0124
# Epoch 4000 | Loss_I: 0.0270 | Loss_B: 0.0026 | Loss_F: 0.0121
# Epoch 4100 | Loss_I: 0.0263 | Loss_B: 0.0025 | Loss_F: 0.0118
# Epoch 4200 | Loss_I: 0.0257 | Loss_B: 0.0025 | Loss_F: 0.0115
# Epoch 4300 | Loss_I: 0.0251 | Loss_B: 0.0024 | Loss_F: 0.0112
# Epoch 4400 | Loss_I: 0.0246 | Loss_B: 0.0024 | Loss_F: 0.0110
# Epoch 4500 | Loss_I: 0.0240 | Loss_B: 0.0023 | Loss_F: 0.0108
# Epoch 4600 | Loss_I: 0.0235 | Loss_B: 0.0023 | Loss_F: 0.0105
# Epoch 4700 | Loss_I: 0.0230 | Loss_B: 0.0022 | Loss_F: 0.0103
# Epoch 4800 | Loss_I: 0.0225 | Loss_B: 0.0022 | Loss_F: 0.0101
# Epoch 4900 | Loss_I: 0.0221 | Loss_B: 0.0021 | Loss_F: 0.0099
# Epoch 5000 | Loss_I: 0.0216 | Loss_B: 0.0021 | Loss_F: 0.0097
# Current device: cuda
# Data generation completed
# Epoch 100 | Loss_I: 0.1246 | Loss_B: 0.0397 | Loss_F: 0.0159
# Epoch 200 | Loss_I: 0.0691 | Loss_B: 0.0222 | Loss_F: 0.0152
# Epoch 300 | Loss_I: 0.0476 | Loss_B: 0.0157 | Loss_F: 0.0135
# Epoch 400 | Loss_I: 0.0361 | Loss_B: 0.0120 | Loss_F: 0.0112
# Epoch 500 | Loss_I: 0.0290 | Loss_B: 0.0097 | Loss_F: 0.0096
# Epoch 600 | Loss_I: 0.0243 | Loss_B: 0.0082 | Loss_F: 0.0082
# Epoch 700 | Loss_I: 0.0209 | Loss_B: 0.0071 | Loss_F: 0.0073
# Epoch 800 | Loss_I: 0.0183 | Loss_B: 0.0062 | Loss_F: 0.0065
# Epoch 900 | Loss_I: 0.0163 | Loss_B: 0.0055 | Loss_F: 0.0059
# Epoch 1000 | Loss_I: 0.0147 | Loss_B: 0.0050 | Loss_F: 0.0054
# Epoch 1100 | Loss_I: 0.0134 | Loss_B: 0.0046 | Loss_F: 0.0049
# Epoch 1200 | Loss_I: 0.0123 | Loss_B: 0.0042 | Loss_F: 0.0046
# Epoch 1300 | Loss_I: 0.0114 | Loss_B: 0.0039 | Loss_F: 0.0043
# Epoch 1400 | Loss_I: 0.0106 | Loss_B: 0.0036 | Loss_F: 0.0040
# Epoch 1500 | Loss_I: 0.0099 | Loss_B: 0.0034 | Loss_F: 0.0038
# Epoch 1600 | Loss_I: 0.0093 | Loss_B: 0.0032 | Loss_F: 0.0036
# Epoch 1700 | Loss_I: 0.0087 | Loss_B: 0.0030 | Loss_F: 0.0034
# Epoch 1800 | Loss_I: 0.0082 | Loss_B: 0.0029 | Loss_F: 0.0033
# Epoch 1900 | Loss_I: 0.0078 | Loss_B: 0.0027 | Loss_F: 0.0031
# Epoch 2000 | Loss_I: 0.0074 | Loss_B: 0.0026 | Loss_F: 0.0030
# Epoch 2100 | Loss_I: 0.0071 | Loss_B: 0.0025 | Loss_F: 0.0029
# Epoch 2200 | Loss_I: 0.0068 | Loss_B: 0.0024 | Loss_F: 0.0027
# Epoch 2300 | Loss_I: 0.0065 | Loss_B: 0.0023 | Loss_F: 0.0026
# Epoch 2400 | Loss_I: 0.0062 | Loss_B: 0.0022 | Loss_F: 0.0026
# Epoch 2500 | Loss_I: 0.0060 | Loss_B: 0.0021 | Loss_F: 0.0025
# Epoch 2600 | Loss_I: 0.0057 | Loss_B: 0.0020 | Loss_F: 0.0024
# Epoch 2700 | Loss_I: 0.0055 | Loss_B: 0.0020 | Loss_F: 0.0023
# Epoch 2800 | Loss_I: 0.0053 | Loss_B: 0.0019 | Loss_F: 0.0022
# Epoch 2900 | Loss_I: 0.0052 | Loss_B: 0.0018 | Loss_F: 0.0022
# Epoch 3000 | Loss_I: 0.0050 | Loss_B: 0.0018 | Loss_F: 0.0021
# Epoch 3100 | Loss_I: 0.0048 | Loss_B: 0.0017 | Loss_F: 0.0021
# Epoch 3200 | Loss_I: 0.0047 | Loss_B: 0.0017 | Loss_F: 0.0020
# Epoch 3300 | Loss_I: 0.0045 | Loss_B: 0.0016 | Loss_F: 0.0020
# Epoch 3400 | Loss_I: 0.0044 | Loss_B: 0.0016 | Loss_F: 0.0019
# Epoch 3500 | Loss_I: 0.0043 | Loss_B: 0.0016 | Loss_F: 0.0019
# Epoch 3600 | Loss_I: 0.0042 | Loss_B: 0.0015 | Loss_F: 0.0018
# Epoch 3700 | Loss_I: 0.0041 | Loss_B: 0.0015 | Loss_F: 0.0018
# Epoch 3800 | Loss_I: 0.0040 | Loss_B: 0.0014 | Loss_F: 0.0017
# Epoch 3900 | Loss_I: 0.0039 | Loss_B: 0.0014 | Loss_F: 0.0017
# Epoch 4000 | Loss_I: 0.0038 | Loss_B: 0.0014 | Loss_F: 0.0017
# Epoch 4100 | Loss_I: 0.0037 | Loss_B: 0.0013 | Loss_F: 0.0016
# Epoch 4200 | Loss_I: 0.0036 | Loss_B: 0.0013 | Loss_F: 0.0016
# Epoch 4300 | Loss_I: 0.0035 | Loss_B: 0.0013 | Loss_F: 0.0016
# Epoch 4400 | Loss_I: 0.0034 | Loss_B: 0.0013 | Loss_F: 0.0016
# Epoch 4500 | Loss_I: 0.0034 | Loss_B: 0.0012 | Loss_F: 0.0015
# Epoch 4600 | Loss_I: 0.0033 | Loss_B: 0.0012 | Loss_F: 0.0015
# Epoch 4700 | Loss_I: 0.0032 | Loss_B: 0.0012 | Loss_F: 0.0015
# Epoch 4800 | Loss_I: 0.0032 | Loss_B: 0.0012 | Loss_F: 0.0014
# Epoch 4900 | Loss_I: 0.0031 | Loss_B: 0.0011 | Loss_F: 0.0014
# Epoch 5000 | Loss_I: 0.0030 | Loss_B: 0.0011 | Loss_F: 0.0014
# Current device: cuda
# Data generation completed
# Epoch 100 | Loss_I: 0.1343 | Loss_B: 0.0447 | Loss_F: 0.0133
# Epoch 200 | Loss_I: 0.0736 | Loss_B: 0.0250 | Loss_F: 0.0127
# Epoch 300 | Loss_I: 0.0511 | Loss_B: 0.0176 | Loss_F: 0.0118
# Epoch 400 | Loss_I: 0.0387 | Loss_B: 0.0133 | Loss_F: 0.0098
# Epoch 500 | Loss_I: 0.0313 | Loss_B: 0.0107 | Loss_F: 0.0087
# Epoch 600 | Loss_I: 0.0261 | Loss_B: 0.0089 | Loss_F: 0.0073
# Epoch 700 | Loss_I: 0.0224 | Loss_B: 0.0077 | Loss_F: 0.0064
# Epoch 800 | Loss_I: 0.0196 | Loss_B: 0.0068 | Loss_F: 0.0057
# Epoch 900 | Loss_I: 0.0175 | Loss_B: 0.0060 | Loss_F: 0.0052
# Epoch 1000 | Loss_I: 0.0158 | Loss_B: 0.0055 | Loss_F: 0.0047
# Epoch 1100 | Loss_I: 0.0143 | Loss_B: 0.0050 | Loss_F: 0.0043
# Epoch 1200 | Loss_I: 0.0132 | Loss_B: 0.0046 | Loss_F: 0.0040
# Epoch 1300 | Loss_I: 0.0122 | Loss_B: 0.0043 | Loss_F: 0.0038
# Epoch 1400 | Loss_I: 0.0113 | Loss_B: 0.0040 | Loss_F: 0.0035
# Epoch 1500 | Loss_I: 0.0106 | Loss_B: 0.0037 | Loss_F: 0.0033
# Epoch 1600 | Loss_I: 0.0099 | Loss_B: 0.0035 | Loss_F: 0.0032
# Epoch 1700 | Loss_I: 0.0093 | Loss_B: 0.0033 | Loss_F: 0.0030
# Epoch 1800 | Loss_I: 0.0088 | Loss_B: 0.0031 | Loss_F: 0.0029
# Epoch 1900 | Loss_I: 0.0084 | Loss_B: 0.0030 | Loss_F: 0.0027
# Epoch 2000 | Loss_I: 0.0080 | Loss_B: 0.0028 | Loss_F: 0.0026
# Epoch 2100 | Loss_I: 0.0076 | Loss_B: 0.0027 | Loss_F: 0.0025
# Epoch 2200 | Loss_I: 0.0072 | Loss_B: 0.0026 | Loss_F: 0.0024
# Epoch 2300 | Loss_I: 0.0069 | Loss_B: 0.0025 | Loss_F: 0.0023
# Epoch 2400 | Loss_I: 0.0066 | Loss_B: 0.0024 | Loss_F: 0.0023
# Epoch 2500 | Loss_I: 0.0064 | Loss_B: 0.0023 | Loss_F: 0.0022
# Epoch 2600 | Loss_I: 0.0061 | Loss_B: 0.0022 | Loss_F: 0.0021
# Epoch 2700 | Loss_I: 0.0059 | Loss_B: 0.0022 | Loss_F: 0.0020
# Epoch 2800 | Loss_I: 0.0057 | Loss_B: 0.0021 | Loss_F: 0.0020
# Epoch 2900 | Loss_I: 0.0055 | Loss_B: 0.0020 | Loss_F: 0.0019
# Epoch 3000 | Loss_I: 0.0053 | Loss_B: 0.0020 | Loss_F: 0.0019
# Epoch 3100 | Loss_I: 0.0052 | Loss_B: 0.0019 | Loss_F: 0.0018
# Epoch 3200 | Loss_I: 0.0050 | Loss_B: 0.0018 | Loss_F: 0.0018
# Epoch 3300 | Loss_I: 0.0049 | Loss_B: 0.0018 | Loss_F: 0.0017
# Epoch 3400 | Loss_I: 0.0047 | Loss_B: 0.0017 | Loss_F: 0.0017
# Epoch 3500 | Loss_I: 0.0046 | Loss_B: 0.0017 | Loss_F: 0.0017
# Epoch 3600 | Loss_I: 0.0045 | Loss_B: 0.0017 | Loss_F: 0.0016
# Epoch 3700 | Loss_I: 0.0044 | Loss_B: 0.0016 | Loss_F: 0.0016
# Epoch 3800 | Loss_I: 0.0042 | Loss_B: 0.0016 | Loss_F: 0.0015
# Epoch 3900 | Loss_I: 0.0041 | Loss_B: 0.0015 | Loss_F: 0.0015
# Epoch 4000 | Loss_I: 0.0040 | Loss_B: 0.0015 | Loss_F: 0.0015
# Epoch 4100 | Loss_I: 0.0039 | Loss_B: 0.0015 | Loss_F: 0.0015
# Epoch 4200 | Loss_I: 0.0038 | Loss_B: 0.0014 | Loss_F: 0.0014
# Epoch 4300 | Loss_I: 0.0038 | Loss_B: 0.0014 | Loss_F: 0.0014
# Epoch 4400 | Loss_I: 0.0037 | Loss_B: 0.0014 | Loss_F: 0.0014
# Epoch 4500 | Loss_I: 0.0036 | Loss_B: 0.0014 | Loss_F: 0.0014
# Epoch 4600 | Loss_I: 0.0035 | Loss_B: 0.0013 | Loss_F: 0.0013
# Epoch 4700 | Loss_I: 0.0035 | Loss_B: 0.0013 | Loss_F: 0.0013
# Epoch 4800 | Loss_I: 0.0034 | Loss_B: 0.0013 | Loss_F: 0.0013
# Epoch 4900 | Loss_I: 0.0033 | Loss_B: 0.0013 | Loss_F: 0.0013
# Epoch 5000 | Loss_I: 0.0032 | Loss_B: 0.0012 | Loss_F: 0.0013
# Current device: cuda
# Data generation completed
# Epoch 100 | Loss_I: 0.1127 | Loss_B: 0.0357 | Loss_F: 0.0176
# Epoch 200 | Loss_I: 0.0652 | Loss_B: 0.0213 | Loss_F: 0.0167
# Epoch 300 | Loss_I: 0.0456 | Loss_B: 0.0156 | Loss_F: 0.0153
# Epoch 400 | Loss_I: 0.0348 | Loss_B: 0.0121 | Loss_F: 0.0132
# Epoch 500 | Loss_I: 0.0282 | Loss_B: 0.0099 | Loss_F: 0.0116
# Epoch 600 | Loss_I: 0.0237 | Loss_B: 0.0083 | Loss_F: 0.0102
# Epoch 700 | Loss_I: 0.0203 | Loss_B: 0.0071 | Loss_F: 0.0088
# Epoch 800 | Loss_I: 0.0178 | Loss_B: 0.0063 | Loss_F: 0.0079
# Epoch 900 | Loss_I: 0.0159 | Loss_B: 0.0056 | Loss_F: 0.0071
# Epoch 1000 | Loss_I: 0.0143 | Loss_B: 0.0050 | Loss_F: 0.0065
# Epoch 1100 | Loss_I: 0.0130 | Loss_B: 0.0046 | Loss_F: 0.0060
# Epoch 1200 | Loss_I: 0.0119 | Loss_B: 0.0042 | Loss_F: 0.0056
# Epoch 1300 | Loss_I: 0.0110 | Loss_B: 0.0039 | Loss_F: 0.0052
# Epoch 1400 | Loss_I: 0.0103 | Loss_B: 0.0036 | Loss_F: 0.0049
# Epoch 1500 | Loss_I: 0.0096 | Loss_B: 0.0034 | Loss_F: 0.0045
# Epoch 1600 | Loss_I: 0.0090 | Loss_B: 0.0032 | Loss_F: 0.0043
# Epoch 1700 | Loss_I: 0.0085 | Loss_B: 0.0030 | Loss_F: 0.0041
# Epoch 1800 | Loss_I: 0.0080 | Loss_B: 0.0028 | Loss_F: 0.0039
# Epoch 1900 | Loss_I: 0.0076 | Loss_B: 0.0027 | Loss_F: 0.0037
# Epoch 2000 | Loss_I: 0.0072 | Loss_B: 0.0026 | Loss_F: 0.0035
# Epoch 2100 | Loss_I: 0.0069 | Loss_B: 0.0025 | Loss_F: 0.0034
# Epoch 2200 | Loss_I: 0.0066 | Loss_B: 0.0024 | Loss_F: 0.0033
# Epoch 2300 | Loss_I: 0.0063 | Loss_B: 0.0023 | Loss_F: 0.0031
# Epoch 2400 | Loss_I: 0.0060 | Loss_B: 0.0022 | Loss_F: 0.0030
# Epoch 2500 | Loss_I: 0.0058 | Loss_B: 0.0021 | Loss_F: 0.0029
# Epoch 2600 | Loss_I: 0.0056 | Loss_B: 0.0020 | Loss_F: 0.0028
# Epoch 2700 | Loss_I: 0.0054 | Loss_B: 0.0019 | Loss_F: 0.0027
# Epoch 2800 | Loss_I: 0.0052 | Loss_B: 0.0019 | Loss_F: 0.0026
# Epoch 2900 | Loss_I: 0.0050 | Loss_B: 0.0018 | Loss_F: 0.0026
# Epoch 3000 | Loss_I: 0.0049 | Loss_B: 0.0018 | Loss_F: 0.0025
# Epoch 3100 | Loss_I: 0.0047 | Loss_B: 0.0017 | Loss_F: 0.0024
# Epoch 3200 | Loss_I: 0.0046 | Loss_B: 0.0017 | Loss_F: 0.0023
# Epoch 3300 | Loss_I: 0.0044 | Loss_B: 0.0016 | Loss_F: 0.0023
# Epoch 3400 | Loss_I: 0.0043 | Loss_B: 0.0016 | Loss_F: 0.0022
# Epoch 3500 | Loss_I: 0.0042 | Loss_B: 0.0015 | Loss_F: 0.0022
# Epoch 3600 | Loss_I: 0.0041 | Loss_B: 0.0015 | Loss_F: 0.0021
# Epoch 3700 | Loss_I: 0.0040 | Loss_B: 0.0015 | Loss_F: 0.0021
# Epoch 3800 | Loss_I: 0.0039 | Loss_B: 0.0014 | Loss_F: 0.0020
# Epoch 3900 | Loss_I: 0.0038 | Loss_B: 0.0014 | Loss_F: 0.0020
# Epoch 4000 | Loss_I: 0.0037 | Loss_B: 0.0014 | Loss_F: 0.0019
# Epoch 4100 | Loss_I: 0.0036 | Loss_B: 0.0013 | Loss_F: 0.0019
# Epoch 4200 | Loss_I: 0.0035 | Loss_B: 0.0013 | Loss_F: 0.0018
# Epoch 4300 | Loss_I: 0.0034 | Loss_B: 0.0013 | Loss_F: 0.0018
# Epoch 4400 | Loss_I: 0.0034 | Loss_B: 0.0012 | Loss_F: 0.0018
# Epoch 4500 | Loss_I: 0.0033 | Loss_B: 0.0012 | Loss_F: 0.0017
# Epoch 4600 | Loss_I: 0.0032 | Loss_B: 0.0012 | Loss_F: 0.0017
# Epoch 4700 | Loss_I: 0.0031 | Loss_B: 0.0012 | Loss_F: 0.0017
# Epoch 4800 | Loss_I: 0.0031 | Loss_B: 0.0011 | Loss_F: 0.0016
# Epoch 4900 | Loss_I: 0.0030 | Loss_B: 0.0011 | Loss_F: 0.0016
# Epoch 5000 | Loss_I: 0.0030 | Loss_B: 0.0011 | Loss_F: 0.0016

# %%
x = np.arange(4)
methods = ['PINN', 'zero-shot', 'MAML', 'adapted MAML']
values = [mean_nrmse_pinn, mean_nrmse_zs, mean_nrmse_maml, mean_nrmse_adapt_maml]
yerr = [(high_nrmse_pinn - low_nrmse_pinn) / np.sqrt(5), (high_nrmse_zs - low_nrmse_zs) / np.sqrt(5), (high_nrmse_maml - low_nrmse_maml) / np.sqrt(5), (high_nrmse_adapt_maml - low_nrmse_adapt_maml)/ np.sqrt(5)] 
colors = ['r', 'b', 'g', 'y']

plt.bar(x, values, color=colors, yerr=yerr, capsize=10)
plt.xticks(x, methods)
plt.yscale('log')
plt.ylabel('NRMSE')
plt.title('NRMSEs (out-of-distribution)')

plt.show()
