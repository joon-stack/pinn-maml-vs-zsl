# %%
from maml import *
import matplotlib.pyplot as plt
import os

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "1"

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Current device:", device)
# Out:
# Current device: cuda

# %%
maml = MAML(5, 0.01, 0.0005, 0, 2, 1, -1, 1, eqname='poisson', zero_shot=True, load=False, modelpath='models/poisson_zs_2000_ref.data')
# maml = MAML(5, 0.01, 0.0001, 10, 2, 100, -1, 1, eqname='burgers', zero_shot=False, load=False, modelpath='models/model_ref/burgers_zs_1000_ref.data')
# maml = MAML(5, 0.01, 0.0001, 0, 2, 1, low=-1, high=1, eqname='poisson')

train_loss, val_loss, val_ood_loss, nrmse, model = maml.train(5000, 100, 100)
# Out:
# Initializing MAML-PINN model
# Current device:  cuda
# cuda
# Zero shot mode is True
# Finished initialization of MAML-PINN model
# Start MAML training at iteration 0
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 1.0920 | Inner_loss_F: 0.1636 | Inner_loss: 11.0838 | NRMSE: 56.5975
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.2231 | Inner_loss_F: 0.1486 | Inner_loss: 2.3795 | NRMSE: 0.3604
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.9579 | Inner_loss_F: 2.8353 | Inner_loss: 12.4141 | NRMSE: 71.5356
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.5999 | Inner_loss_F: 2.4096 | Inner_loss: 8.4088 | NRMSE: 2.7348
# C:\Users\fembem\anaconda3\envs\torch-1.10.1\lib\site-packages\numpy\core\fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fembem\anaconda3\envs\torch-1.10.1\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Step 20 Pre-Adapt | Inner_loss_B: 0.8942 | Inner_loss_F: 0.2466 | Inner_loss: 9.1882
# Step 20 Post-Adapt | Inner_loss_B: 0.1870 | Inner_loss_F: 0.2151 | Inner_loss: 2.0854
# Step 40 Pre-Adapt | Inner_loss_B: 0.7574 | Inner_loss_F: 0.2036 | Inner_loss: 7.7780
# Step 40 Post-Adapt | Inner_loss_B: 0.1429 | Inner_loss_F: 0.1774 | Inner_loss: 1.6063
# Step 60 Pre-Adapt | Inner_loss_B: 0.6694 | Inner_loss_F: 0.2195 | Inner_loss: 6.9135
# Step 60 Post-Adapt | Inner_loss_B: 0.1309 | Inner_loss_F: 0.1840 | Inner_loss: 1.4932
# Step 80 Pre-Adapt | Inner_loss_B: 0.6611 | Inner_loss_F: 0.1763 | Inner_loss: 6.7874
# Step 80 Post-Adapt | Inner_loss_B: 0.1035 | Inner_loss_F: 0.1463 | Inner_loss: 1.1816
# Model saved
# Step 100 Pre-Adapt | Inner_loss_B: 0.6088 | Inner_loss_F: 0.2183 | Inner_loss: 6.3060
# Step 100 Post-Adapt | Inner_loss_B: 0.0831 | Inner_loss_F: 0.1734 | Inner_loss: 1.0042
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.6724 | Inner_loss_F: 0.1276 | Inner_loss: 6.8511 | NRMSE: 3.2178
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0815 | Inner_loss_F: 0.0998 | Inner_loss: 0.9149 | NRMSE: 0.2225
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7776 | Inner_loss_F: 2.4042 | Inner_loss: 10.1806 | NRMSE: 4.6012
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2294 | Inner_loss_F: 2.0689 | Inner_loss: 4.3629 | NRMSE: 1.4813
# Step 120 Pre-Adapt | Inner_loss_B: 0.6470 | Inner_loss_F: 0.1896 | Inner_loss: 6.6598
# Step 120 Post-Adapt | Inner_loss_B: 0.0524 | Inner_loss_F: 0.1243 | Inner_loss: 0.6481
# Step 140 Pre-Adapt | Inner_loss_B: 0.6582 | Inner_loss_F: 0.1918 | Inner_loss: 6.7742
# Step 140 Post-Adapt | Inner_loss_B: 0.0337 | Inner_loss_F: 0.1249 | Inner_loss: 0.4622
# Step 160 Pre-Adapt | Inner_loss_B: 0.6780 | Inner_loss_F: 0.1674 | Inner_loss: 6.9472
# Step 160 Post-Adapt | Inner_loss_B: 0.0180 | Inner_loss_F: 0.1144 | Inner_loss: 0.2945
# Step 180 Pre-Adapt | Inner_loss_B: 0.6839 | Inner_loss_F: 0.1516 | Inner_loss: 6.9904
# Step 180 Post-Adapt | Inner_loss_B: 0.0084 | Inner_loss_F: 0.1134 | Inner_loss: 0.1977
# Model saved
# Step 200 Pre-Adapt | Inner_loss_B: 0.5453 | Inner_loss_F: 0.1657 | Inner_loss: 5.6185
# Step 200 Post-Adapt | Inner_loss_B: 0.0027 | Inner_loss_F: 0.1069 | Inner_loss: 0.1342
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.5491 | Inner_loss_F: 0.1235 | Inner_loss: 5.6145 | NRMSE: 2.1580
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0025 | Inner_loss_F: 0.0950 | Inner_loss: 0.1200 | NRMSE: 0.0863
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.5209 | Inner_loss_F: 2.4700 | Inner_loss: 7.6788 | NRMSE: 4.9791
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.0156 | Inner_loss_F: 0.4923 | Inner_loss: 0.6487 | NRMSE: 0.6937
# Step 220 Pre-Adapt | Inner_loss_B: 0.3793 | Inner_loss_F: 0.1467 | Inner_loss: 3.9402
# Step 220 Post-Adapt | Inner_loss_B: 0.0021 | Inner_loss_F: 0.0860 | Inner_loss: 0.1068
# Step 240 Pre-Adapt | Inner_loss_B: 0.1875 | Inner_loss_F: 0.1933 | Inner_loss: 2.0683
# Step 240 Post-Adapt | Inner_loss_B: 0.0032 | Inner_loss_F: 0.0892 | Inner_loss: 0.1213
# Step 260 Pre-Adapt | Inner_loss_B: 0.2139 | Inner_loss_F: 0.2875 | Inner_loss: 2.4260
# Step 260 Post-Adapt | Inner_loss_B: 0.0098 | Inner_loss_F: 0.0976 | Inner_loss: 0.1953
# Step 280 Pre-Adapt | Inner_loss_B: 0.2371 | Inner_loss_F: 0.2568 | Inner_loss: 2.6275
# Step 280 Post-Adapt | Inner_loss_B: 0.0076 | Inner_loss_F: 0.0948 | Inner_loss: 0.1706
# Model saved
# Step 300 Pre-Adapt | Inner_loss_B: 0.2279 | Inner_loss_F: 0.2548 | Inner_loss: 2.5337
# Step 300 Post-Adapt | Inner_loss_B: 0.0066 | Inner_loss_F: 0.0959 | Inner_loss: 0.1620
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.2357 | Inner_loss_F: 0.2654 | Inner_loss: 2.6220 | NRMSE: 0.6835
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0080 | Inner_loss_F: 0.0853 | Inner_loss: 0.1657 | NRMSE: 0.1119
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2527 | Inner_loss_F: 2.4271 | Inner_loss: 4.9546 | NRMSE: 2.2278
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.1913 | Inner_loss_F: 0.9134 | Inner_loss: 2.8268 | NRMSE: 0.7539
# Step 320 Pre-Adapt | Inner_loss_B: 0.1794 | Inner_loss_F: 0.2045 | Inner_loss: 1.9989
# Step 320 Post-Adapt | Inner_loss_B: 0.0045 | Inner_loss_F: 0.0771 | Inner_loss: 0.1220
# Step 340 Pre-Adapt | Inner_loss_B: 0.1502 | Inner_loss_F: 0.2284 | Inner_loss: 1.7307
# Step 340 Post-Adapt | Inner_loss_B: 0.0136 | Inner_loss_F: 0.0754 | Inner_loss: 0.2110
# Step 360 Pre-Adapt | Inner_loss_B: 0.2445 | Inner_loss_F: 0.2514 | Inner_loss: 2.6962
# Step 360 Post-Adapt | Inner_loss_B: 0.0070 | Inner_loss_F: 0.0747 | Inner_loss: 0.1447
# Step 380 Pre-Adapt | Inner_loss_B: 0.1927 | Inner_loss_F: 0.2085 | Inner_loss: 2.1355
# Step 380 Post-Adapt | Inner_loss_B: 0.0076 | Inner_loss_F: 0.0755 | Inner_loss: 0.1511
# Model saved
# Step 400 Pre-Adapt | Inner_loss_B: 0.1976 | Inner_loss_F: 0.2342 | Inner_loss: 2.2100
# Step 400 Post-Adapt | Inner_loss_B: 0.0084 | Inner_loss_F: 0.0896 | Inner_loss: 0.1738
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.2097 | Inner_loss_F: 0.2248 | Inner_loss: 2.3220 | NRMSE: 0.6063
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0110 | Inner_loss_F: 0.0744 | Inner_loss: 0.1847 | NRMSE: 0.1221
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2218 | Inner_loss_F: 2.6231 | Inner_loss: 4.8416 | NRMSE: 1.9491
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.1955 | Inner_loss_F: 0.9572 | Inner_loss: 2.9123 | NRMSE: 0.7662
# Step 420 Pre-Adapt | Inner_loss_B: 0.1661 | Inner_loss_F: 0.2191 | Inner_loss: 1.8805
# Step 420 Post-Adapt | Inner_loss_B: 0.0033 | Inner_loss_F: 0.0881 | Inner_loss: 0.1209
# Step 440 Pre-Adapt | Inner_loss_B: 0.2082 | Inner_loss_F: 0.2339 | Inner_loss: 2.3155
# Step 440 Post-Adapt | Inner_loss_B: 0.0090 | Inner_loss_F: 0.0741 | Inner_loss: 0.1646
# Step 460 Pre-Adapt | Inner_loss_B: 0.1758 | Inner_loss_F: 0.2370 | Inner_loss: 1.9953
# Step 460 Post-Adapt | Inner_loss_B: 0.0108 | Inner_loss_F: 0.0787 | Inner_loss: 0.1868
# Step 480 Pre-Adapt | Inner_loss_B: 0.1422 | Inner_loss_F: 0.2281 | Inner_loss: 1.6497
# Step 480 Post-Adapt | Inner_loss_B: 0.0070 | Inner_loss_F: 0.0704 | Inner_loss: 0.1407
# Model saved
# Step 500 Pre-Adapt | Inner_loss_B: 0.2520 | Inner_loss_F: 0.2366 | Inner_loss: 2.7567
# Step 500 Post-Adapt | Inner_loss_B: 0.0100 | Inner_loss_F: 0.0665 | Inner_loss: 0.1663
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.2597 | Inner_loss_F: 0.2646 | Inner_loss: 2.8619 | NRMSE: 0.7228
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0116 | Inner_loss_F: 0.0680 | Inner_loss: 0.1844 | NRMSE: 0.1186
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.1980 | Inner_loss_F: 2.1153 | Inner_loss: 4.0954 | NRMSE: 1.9852
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2777 | Inner_loss_F: 1.0030 | Inner_loss: 3.7803 | NRMSE: 0.7407
# Step 520 Pre-Adapt | Inner_loss_B: 0.2503 | Inner_loss_F: 0.2294 | Inner_loss: 2.7325
# Step 520 Post-Adapt | Inner_loss_B: 0.0156 | Inner_loss_F: 0.0736 | Inner_loss: 0.2293
# Step 540 Pre-Adapt | Inner_loss_B: 0.2290 | Inner_loss_F: 0.2643 | Inner_loss: 2.5544
# Step 540 Post-Adapt | Inner_loss_B: 0.0196 | Inner_loss_F: 0.0702 | Inner_loss: 0.2659
# Step 560 Pre-Adapt | Inner_loss_B: 0.2407 | Inner_loss_F: 0.2304 | Inner_loss: 2.6377
# Step 560 Post-Adapt | Inner_loss_B: 0.0180 | Inner_loss_F: 0.0814 | Inner_loss: 0.2610
# Step 580 Pre-Adapt | Inner_loss_B: 0.1994 | Inner_loss_F: 0.2654 | Inner_loss: 2.2595
# Step 580 Post-Adapt | Inner_loss_B: 0.0206 | Inner_loss_F: 0.0837 | Inner_loss: 0.2892
# Model saved
# Step 600 Pre-Adapt | Inner_loss_B: 0.1200 | Inner_loss_F: 0.3648 | Inner_loss: 1.5646
# Step 600 Post-Adapt | Inner_loss_B: 0.0131 | Inner_loss_F: 0.1125 | Inner_loss: 0.2438
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.0959 | Inner_loss_F: 0.3431 | Inner_loss: 1.3021 | NRMSE: 0.2554
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0128 | Inner_loss_F: 0.0657 | Inner_loss: 0.1937 | NRMSE: 0.1437
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.0447 | Inner_loss_F: 1.9095 | Inner_loss: 2.3567 | NRMSE: 1.1217
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.5164 | Inner_loss_F: 1.7466 | Inner_loss: 6.9105 | NRMSE: 2.1488
# Step 620 Pre-Adapt | Inner_loss_B: 0.0649 | Inner_loss_F: 0.5376 | Inner_loss: 1.1869
# Step 620 Post-Adapt | Inner_loss_B: 0.1635 | Inner_loss_F: 0.1367 | Inner_loss: 1.7715
# Step 640 Pre-Adapt | Inner_loss_B: 0.0767 | Inner_loss_F: 0.4490 | Inner_loss: 1.2159
# Step 640 Post-Adapt | Inner_loss_B: 0.0678 | Inner_loss_F: 0.0861 | Inner_loss: 0.7646
# Step 660 Pre-Adapt | Inner_loss_B: 0.0710 | Inner_loss_F: 0.4094 | Inner_loss: 1.1191
# Step 660 Post-Adapt | Inner_loss_B: 0.1269 | Inner_loss_F: 0.0904 | Inner_loss: 1.3594
# Step 680 Pre-Adapt | Inner_loss_B: 0.0627 | Inner_loss_F: 0.3781 | Inner_loss: 1.0051
# Step 680 Post-Adapt | Inner_loss_B: 0.2911 | Inner_loss_F: 0.0964 | Inner_loss: 3.0072
# Model saved
# Step 700 Pre-Adapt | Inner_loss_B: 0.2720 | Inner_loss_F: 0.2776 | Inner_loss: 2.9979
# Step 700 Post-Adapt | Inner_loss_B: 0.0116 | Inner_loss_F: 0.0646 | Inner_loss: 0.1810
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.2835 | Inner_loss_F: 0.2814 | Inner_loss: 3.1162 | NRMSE: 0.7740
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0109 | Inner_loss_F: 0.0650 | Inner_loss: 0.1745 | NRMSE: 0.1135
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.1327 | Inner_loss_F: 2.5378 | Inner_loss: 3.8647 | NRMSE: 1.8654
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2366 | Inner_loss_F: 0.9427 | Inner_loss: 3.3089 | NRMSE: 0.8127
# Step 720 Pre-Adapt | Inner_loss_B: 0.2090 | Inner_loss_F: 0.2015 | Inner_loss: 2.2918
# Step 720 Post-Adapt | Inner_loss_B: 0.0199 | Inner_loss_F: 0.0582 | Inner_loss: 0.2567
# Step 740 Pre-Adapt | Inner_loss_B: 0.2035 | Inner_loss_F: 0.2023 | Inner_loss: 2.2370
# Step 740 Post-Adapt | Inner_loss_B: 0.0094 | Inner_loss_F: 0.0702 | Inner_loss: 0.1644
# Step 760 Pre-Adapt | Inner_loss_B: 0.0971 | Inner_loss_F: 0.2979 | Inner_loss: 1.2689
# Step 760 Post-Adapt | Inner_loss_B: 0.0184 | Inner_loss_F: 0.0824 | Inner_loss: 0.2661
# Step 780 Pre-Adapt | Inner_loss_B: 0.1202 | Inner_loss_F: 0.4495 | Inner_loss: 1.6513
# Step 780 Post-Adapt | Inner_loss_B: 0.0560 | Inner_loss_F: 0.0929 | Inner_loss: 0.6529
# Model saved
# Step 800 Pre-Adapt | Inner_loss_B: 0.1214 | Inner_loss_F: 0.4696 | Inner_loss: 1.6838
# Step 800 Post-Adapt | Inner_loss_B: 0.0315 | Inner_loss_F: 0.0812 | Inner_loss: 0.3958
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.1198 | Inner_loss_F: 0.4155 | Inner_loss: 1.6138 | NRMSE: 0.2336
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0395 | Inner_loss_F: 0.0570 | Inner_loss: 0.4518 | NRMSE: 0.1600
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.0449 | Inner_loss_F: 2.5858 | Inner_loss: 3.0350 | NRMSE: 0.7849
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.6980 | Inner_loss_F: 1.8645 | Inner_loss: 8.8443 | NRMSE: 2.4043
# Step 820 Pre-Adapt | Inner_loss_B: 0.1414 | Inner_loss_F: 0.5468 | Inner_loss: 1.9608
# Step 820 Post-Adapt | Inner_loss_B: 0.1182 | Inner_loss_F: 0.1025 | Inner_loss: 1.2845
# Step 840 Pre-Adapt | Inner_loss_B: 0.1693 | Inner_loss_F: 0.5529 | Inner_loss: 2.2464
# Step 840 Post-Adapt | Inner_loss_B: 0.0721 | Inner_loss_F: 0.0767 | Inner_loss: 0.7973
# Step 860 Pre-Adapt | Inner_loss_B: 0.2162 | Inner_loss_F: 0.6363 | Inner_loss: 2.7980
# Step 860 Post-Adapt | Inner_loss_B: 0.2012 | Inner_loss_F: 0.1119 | Inner_loss: 2.1238
# Step 880 Pre-Adapt | Inner_loss_B: 0.2174 | Inner_loss_F: 0.6470 | Inner_loss: 2.8206
# Step 880 Post-Adapt | Inner_loss_B: 0.0762 | Inner_loss_F: 0.0916 | Inner_loss: 0.8537
# Model saved
# Step 900 Pre-Adapt | Inner_loss_B: 0.2047 | Inner_loss_F: 0.5008 | Inner_loss: 2.5474
# Step 900 Post-Adapt | Inner_loss_B: 0.0964 | Inner_loss_F: 0.0677 | Inner_loss: 1.0322
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.1816 | Inner_loss_F: 0.5365 | Inner_loss: 2.3529 | NRMSE: 0.2943
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0911 | Inner_loss_F: 0.0927 | Inner_loss: 1.0034 | NRMSE: 0.2133
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.0899 | Inner_loss_F: 2.5340 | Inner_loss: 3.4326 | NRMSE: 0.9029
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7950 | Inner_loss_F: 2.0223 | Inner_loss: 9.9724 | NRMSE: 2.3045
# Step 920 Pre-Adapt | Inner_loss_B: 0.2734 | Inner_loss_F: 0.8572 | Inner_loss: 3.5912
# Step 920 Post-Adapt | Inner_loss_B: 0.1044 | Inner_loss_F: 0.1172 | Inner_loss: 1.1610
# Step 940 Pre-Adapt | Inner_loss_B: 0.6034 | Inner_loss_F: 1.1130 | Inner_loss: 7.1467
# Step 940 Post-Adapt | Inner_loss_B: 0.2101 | Inner_loss_F: 0.1118 | Inner_loss: 2.2124
# Step 960 Pre-Adapt | Inner_loss_B: 1.1738 | Inner_loss_F: 1.4498 | Inner_loss: 13.1876
# Step 960 Post-Adapt | Inner_loss_B: 0.0902 | Inner_loss_F: 0.1442 | Inner_loss: 1.0464
# Step 980 Pre-Adapt | Inner_loss_B: 2.4315 | Inner_loss_F: 4.8432 | Inner_loss: 29.1586
# Step 980 Post-Adapt | Inner_loss_B: 0.1704 | Inner_loss_F: 0.1937 | Inner_loss: 1.8975
# Model saved
# Step 1000 Pre-Adapt | Inner_loss_B: 3.9107 | Inner_loss_F: 7.6015 | Inner_loss: 46.7082
# Step 1000 Post-Adapt | Inner_loss_B: 0.1460 | Inner_loss_F: 0.2060 | Inner_loss: 1.6658
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 4.3241 | Inner_loss_F: 10.2859 | Inner_loss: 53.5266 | NRMSE: 0.7217
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.2398 | Inner_loss_F: 0.1514 | Inner_loss: 2.5498 | NRMSE: 0.3738
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 3.0183 | Inner_loss_F: 4.0949 | Inner_loss: 34.2775 | NRMSE: 0.7848
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.6288 | Inner_loss_F: 2.1463 | Inner_loss: 8.4345 | NRMSE: 2.8747
# Step 1020 Pre-Adapt | Inner_loss_B: 4.3255 | Inner_loss_F: 7.1500 | Inner_loss: 50.4051
# Step 1020 Post-Adapt | Inner_loss_B: 0.1787 | Inner_loss_F: 0.2488 | Inner_loss: 2.0363
# Step 1040 Pre-Adapt | Inner_loss_B: 4.6664 | Inner_loss_F: 9.0068 | Inner_loss: 55.6710
# Step 1040 Post-Adapt | Inner_loss_B: 0.2162 | Inner_loss_F: 0.2714 | Inner_loss: 2.4331
# Step 1060 Pre-Adapt | Inner_loss_B: 5.0629 | Inner_loss_F: 8.3733 | Inner_loss: 59.0021
# Step 1060 Post-Adapt | Inner_loss_B: 0.2957 | Inner_loss_F: 0.2204 | Inner_loss: 3.1776
# Step 1080 Pre-Adapt | Inner_loss_B: 5.5517 | Inner_loss_F: 5.5222 | Inner_loss: 61.0393
# Step 1080 Post-Adapt | Inner_loss_B: 0.4107 | Inner_loss_F: 0.2581 | Inner_loss: 4.3649
# Model saved
# Step 1100 Pre-Adapt | Inner_loss_B: 6.1790 | Inner_loss_F: 3.7752 | Inner_loss: 65.5653
# Step 1100 Post-Adapt | Inner_loss_B: 0.5303 | Inner_loss_F: 0.2196 | Inner_loss: 5.5226
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 6.2641 | Inner_loss_F: 4.1729 | Inner_loss: 66.8142 | NRMSE: 0.7121
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 2.2299 | Inner_loss_F: 0.1957 | Inner_loss: 22.4949 | NRMSE: 0.5844
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 3.7332 | Inner_loss_F: 1.9346 | Inner_loss: 39.2665 | NRMSE: 0.6878
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 249.8553 | Inner_loss_F: 3.0172 | Inner_loss: 2501.5701 | NRMSE: 1.1507
# Step 1120 Pre-Adapt | Inner_loss_B: 6.5503 | Inner_loss_F: 0.9050 | Inner_loss: 66.4081
# Step 1120 Post-Adapt | Inner_loss_B: 2.8271 | Inner_loss_F: 0.2433 | Inner_loss: 28.5147
# Step 1140 Pre-Adapt | Inner_loss_B: 7.4730 | Inner_loss_F: 0.3874 | Inner_loss: 75.1176
# Step 1140 Post-Adapt | Inner_loss_B: 2.0068 | Inner_loss_F: 0.3258 | Inner_loss: 20.3940
# Step 1160 Pre-Adapt | Inner_loss_B: 7.9259 | Inner_loss_F: 0.2531 | Inner_loss: 79.5123
# Step 1160 Post-Adapt | Inner_loss_B: 3.3877 | Inner_loss_F: 0.6499 | Inner_loss: 34.5270
# Step 1180 Pre-Adapt | Inner_loss_B: 9.2433 | Inner_loss_F: 0.1806 | Inner_loss: 92.6140
# Step 1180 Post-Adapt | Inner_loss_B: 3.7284 | Inner_loss_F: 0.2177 | Inner_loss: 37.5020
# Model saved
# Step 1200 Pre-Adapt | Inner_loss_B: 10.0236 | Inner_loss_F: 0.1483 | Inner_loss: 100.3839
# Step 1200 Post-Adapt | Inner_loss_B: 5.2412 | Inner_loss_F: 0.1860 | Inner_loss: 52.5981
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 9.7101 | Inner_loss_F: 0.1285 | Inner_loss: 97.2296 | NRMSE: 0.7597
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 2.7463 | Inner_loss_F: 0.1546 | Inner_loss: 27.6177 | NRMSE: 2.9840
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 10.0484 | Inner_loss_F: 1.9964 | Inner_loss: 102.4808 | NRMSE: 0.7870
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 53.5142 | Inner_loss_F: 2.5282 | Inner_loss: 537.6699 | NRMSE: 1.3568
# Step 1220 Pre-Adapt | Inner_loss_B: 9.6772 | Inner_loss_F: 0.1256 | Inner_loss: 96.8974
# Step 1220 Post-Adapt | Inner_loss_B: 2.4689 | Inner_loss_F: 0.1713 | Inner_loss: 24.8604
# Step 1240 Pre-Adapt | Inner_loss_B: 9.9366 | Inner_loss_F: 0.1574 | Inner_loss: 99.5231
# Step 1240 Post-Adapt | Inner_loss_B: 1.1843 | Inner_loss_F: 0.1926 | Inner_loss: 12.0357
# Step 1260 Pre-Adapt | Inner_loss_B: 9.7256 | Inner_loss_F: 0.1662 | Inner_loss: 97.4219
# Step 1260 Post-Adapt | Inner_loss_B: 0.5836 | Inner_loss_F: 0.2022 | Inner_loss: 6.0385
# Step 1280 Pre-Adapt | Inner_loss_B: 9.5333 | Inner_loss_F: 0.1558 | Inner_loss: 95.4886
# Step 1280 Post-Adapt | Inner_loss_B: 0.5142 | Inner_loss_F: 0.1862 | Inner_loss: 5.3277
# Model saved
# Step 1300 Pre-Adapt | Inner_loss_B: 9.6236 | Inner_loss_F: 0.2092 | Inner_loss: 96.4453
# Step 1300 Post-Adapt | Inner_loss_B: 0.3117 | Inner_loss_F: 0.2488 | Inner_loss: 3.3654
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 8.7298 | Inner_loss_F: 0.1330 | Inner_loss: 87.4306 | NRMSE: 0.7488
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.3557 | Inner_loss_F: 0.1613 | Inner_loss: 3.7182 | NRMSE: 0.5829
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 10.3600 | Inner_loss_F: 1.9732 | Inner_loss: 105.5728 | NRMSE: 0.7910
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 8.7584 | Inner_loss_F: 2.5548 | Inner_loss: 90.1385 | NRMSE: 2.0351
# Step 1320 Pre-Adapt | Inner_loss_B: 9.1445 | Inner_loss_F: 0.1240 | Inner_loss: 91.5687
# Step 1320 Post-Adapt | Inner_loss_B: 0.3195 | Inner_loss_F: 0.1431 | Inner_loss: 3.3385
# Step 1340 Pre-Adapt | Inner_loss_B: 9.3967 | Inner_loss_F: 0.1713 | Inner_loss: 94.1386
# Step 1340 Post-Adapt | Inner_loss_B: 0.6905 | Inner_loss_F: 0.1697 | Inner_loss: 7.0742
# Step 1360 Pre-Adapt | Inner_loss_B: 9.4762 | Inner_loss_F: 0.1478 | Inner_loss: 94.9094
# Step 1360 Post-Adapt | Inner_loss_B: 0.9377 | Inner_loss_F: 0.1882 | Inner_loss: 9.5651
# Step 1380 Pre-Adapt | Inner_loss_B: 8.9503 | Inner_loss_F: 0.1723 | Inner_loss: 89.6752
# Step 1380 Post-Adapt | Inner_loss_B: 1.2161 | Inner_loss_F: 0.2199 | Inner_loss: 12.3814
# Model saved
# Step 1400 Pre-Adapt | Inner_loss_B: 9.8379 | Inner_loss_F: 0.2032 | Inner_loss: 98.5820
# Step 1400 Post-Adapt | Inner_loss_B: 0.4718 | Inner_loss_F: 0.2449 | Inner_loss: 4.9627
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 9.0287 | Inner_loss_F: 0.1369 | Inner_loss: 90.4238 | NRMSE: 0.7524
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.4791 | Inner_loss_F: 0.1492 | Inner_loss: 4.9405 | NRMSE: 0.8597
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 11.3675 | Inner_loss_F: 2.2738 | Inner_loss: 115.9483 | NRMSE: 0.8007
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 14.6054 | Inner_loss_F: 2.3780 | Inner_loss: 148.4317 | NRMSE: 4.4448
# Step 1420 Pre-Adapt | Inner_loss_B: 10.0760 | Inner_loss_F: 0.1876 | Inner_loss: 100.9480
# Step 1420 Post-Adapt | Inner_loss_B: 0.3565 | Inner_loss_F: 0.2271 | Inner_loss: 3.7923
# Step 1440 Pre-Adapt | Inner_loss_B: 9.3674 | Inner_loss_F: 0.1952 | Inner_loss: 93.8697
# Step 1440 Post-Adapt | Inner_loss_B: 0.3873 | Inner_loss_F: 0.2173 | Inner_loss: 4.0907
# Step 1460 Pre-Adapt | Inner_loss_B: 9.3984 | Inner_loss_F: 0.1798 | Inner_loss: 94.1642
# Step 1460 Post-Adapt | Inner_loss_B: 0.3550 | Inner_loss_F: 0.1840 | Inner_loss: 3.7343
# Step 1480 Pre-Adapt | Inner_loss_B: 9.5454 | Inner_loss_F: 0.1424 | Inner_loss: 95.5961
# Step 1480 Post-Adapt | Inner_loss_B: 0.2407 | Inner_loss_F: 0.1519 | Inner_loss: 2.5586
# Model saved
# Step 1500 Pre-Adapt | Inner_loss_B: 9.5138 | Inner_loss_F: 0.1547 | Inner_loss: 95.2932
# Step 1500 Post-Adapt | Inner_loss_B: 0.2875 | Inner_loss_F: 0.1451 | Inner_loss: 3.0203
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 8.9984 | Inner_loss_F: 0.1364 | Inner_loss: 90.1200 | NRMSE: 0.7520
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.3113 | Inner_loss_F: 0.1444 | Inner_loss: 3.2576 | NRMSE: 0.4941
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 11.6982 | Inner_loss_F: 2.4480 | Inner_loss: 119.4296 | NRMSE: 0.8038
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 6.2999 | Inner_loss_F: 2.3487 | Inner_loss: 65.3472 | NRMSE: 5.4897
# Step 1520 Pre-Adapt | Inner_loss_B: 9.5717 | Inner_loss_F: 0.1708 | Inner_loss: 95.8882
# Step 1520 Post-Adapt | Inner_loss_B: 0.2656 | Inner_loss_F: 0.1767 | Inner_loss: 2.8328
# Step 1540 Pre-Adapt | Inner_loss_B: 9.7587 | Inner_loss_F: 0.1967 | Inner_loss: 97.7838
# Step 1540 Post-Adapt | Inner_loss_B: 0.2327 | Inner_loss_F: 0.2161 | Inner_loss: 2.5435
# Step 1560 Pre-Adapt | Inner_loss_B: 9.7097 | Inner_loss_F: 0.1603 | Inner_loss: 97.2571
# Step 1560 Post-Adapt | Inner_loss_B: 0.3354 | Inner_loss_F: 0.1775 | Inner_loss: 3.5312
# Step 1580 Pre-Adapt | Inner_loss_B: 9.7899 | Inner_loss_F: 0.1879 | Inner_loss: 98.0868
# Step 1580 Post-Adapt | Inner_loss_B: 0.2236 | Inner_loss_F: 0.1987 | Inner_loss: 2.4342
# Model saved
# Step 1600 Pre-Adapt | Inner_loss_B: 9.9633 | Inner_loss_F: 0.1807 | Inner_loss: 99.8133
# Step 1600 Post-Adapt | Inner_loss_B: 0.3059 | Inner_loss_F: 0.1809 | Inner_loss: 3.2401
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 9.1616 | Inner_loss_F: 0.1358 | Inner_loss: 91.7515 | NRMSE: 0.7540
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.2502 | Inner_loss_F: 0.1394 | Inner_loss: 2.6410 | NRMSE: 0.4094
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 12.0468 | Inner_loss_F: 2.4649 | Inner_loss: 122.9324 | NRMSE: 0.8067
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 5.2683 | Inner_loss_F: 2.5750 | Inner_loss: 55.2582 | NRMSE: 5.8471
# Step 1620 Pre-Adapt | Inner_loss_B: 9.2936 | Inner_loss_F: 0.1665 | Inner_loss: 93.1030
# Step 1620 Post-Adapt | Inner_loss_B: 0.2195 | Inner_loss_F: 0.1660 | Inner_loss: 2.3613
# Step 1640 Pre-Adapt | Inner_loss_B: 9.5747 | Inner_loss_F: 0.2184 | Inner_loss: 95.9651
# Step 1640 Post-Adapt | Inner_loss_B: 0.3107 | Inner_loss_F: 0.2268 | Inner_loss: 3.3335
# Step 1660 Pre-Adapt | Inner_loss_B: 10.0403 | Inner_loss_F: 0.1777 | Inner_loss: 100.5804
# Step 1660 Post-Adapt | Inner_loss_B: 0.1977 | Inner_loss_F: 0.1935 | Inner_loss: 2.1708
# Step 1680 Pre-Adapt | Inner_loss_B: 9.7298 | Inner_loss_F: 0.1484 | Inner_loss: 97.4464
# Step 1680 Post-Adapt | Inner_loss_B: 0.2311 | Inner_loss_F: 0.1776 | Inner_loss: 2.4888
# Model saved
# Step 1700 Pre-Adapt | Inner_loss_B: 9.6901 | Inner_loss_F: 0.1844 | Inner_loss: 97.0851
# Step 1700 Post-Adapt | Inner_loss_B: 0.1948 | Inner_loss_F: 0.1770 | Inner_loss: 2.1249
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 9.3435 | Inner_loss_F: 0.1478 | Inner_loss: 93.5826 | NRMSE: 0.7566
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.1712 | Inner_loss_F: 0.1555 | Inner_loss: 1.8672 | NRMSE: 0.3967
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 12.2300 | Inner_loss_F: 2.4454 | Inner_loss: 124.7454 | NRMSE: 0.8084
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 7.2825 | Inner_loss_F: 3.0815 | Inner_loss: 75.9070 | NRMSE: 5.0753
# Step 1720 Pre-Adapt | Inner_loss_B: 9.8130 | Inner_loss_F: 0.1597 | Inner_loss: 98.2892
# Step 1720 Post-Adapt | Inner_loss_B: 0.2444 | Inner_loss_F: 0.1827 | Inner_loss: 2.6266
# Step 1740 Pre-Adapt | Inner_loss_B: 9.9717 | Inner_loss_F: 0.2002 | Inner_loss: 99.9173
# Step 1740 Post-Adapt | Inner_loss_B: 0.1194 | Inner_loss_F: 0.2009 | Inner_loss: 1.3945
# Step 1760 Pre-Adapt | Inner_loss_B: 10.0963 | Inner_loss_F: 0.2032 | Inner_loss: 101.1663
# Step 1760 Post-Adapt | Inner_loss_B: 0.1621 | Inner_loss_F: 0.2084 | Inner_loss: 1.8296
# Step 1780 Pre-Adapt | Inner_loss_B: 10.3043 | Inner_loss_F: 0.2050 | Inner_loss: 103.2481
# Step 1780 Post-Adapt | Inner_loss_B: 0.1236 | Inner_loss_F: 0.2104 | Inner_loss: 1.4468
# Model saved
# Step 1800 Pre-Adapt | Inner_loss_B: 10.2325 | Inner_loss_F: 0.1709 | Inner_loss: 102.4958
# Step 1800 Post-Adapt | Inner_loss_B: 0.0852 | Inner_loss_F: 0.1799 | Inner_loss: 1.0320
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 9.6475 | Inner_loss_F: 0.1735 | Inner_loss: 96.6483 | NRMSE: 0.7606
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0822 | Inner_loss_F: 0.1991 | Inner_loss: 1.0208 | NRMSE: 0.3722
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 12.5255 | Inner_loss_F: 2.1255 | Inner_loss: 127.3805 | NRMSE: 0.8119
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 6.5929 | Inner_loss_F: 2.6852 | Inner_loss: 68.6140 | NRMSE: 2.1488
# Step 1820 Pre-Adapt | Inner_loss_B: 10.1796 | Inner_loss_F: 0.2020 | Inner_loss: 101.9980
# Step 1820 Post-Adapt | Inner_loss_B: 0.0853 | Inner_loss_F: 0.2396 | Inner_loss: 1.0924
# Step 1840 Pre-Adapt | Inner_loss_B: 10.0453 | Inner_loss_F: 0.1956 | Inner_loss: 100.6485
# Step 1840 Post-Adapt | Inner_loss_B: 0.0712 | Inner_loss_F: 0.2176 | Inner_loss: 0.9301
# Step 1860 Pre-Adapt | Inner_loss_B: 10.2326 | Inner_loss_F: 0.2162 | Inner_loss: 102.5423
# Step 1860 Post-Adapt | Inner_loss_B: 0.0806 | Inner_loss_F: 0.2102 | Inner_loss: 1.0163
# Step 1880 Pre-Adapt | Inner_loss_B: 10.2037 | Inner_loss_F: 0.1827 | Inner_loss: 102.2197
# Step 1880 Post-Adapt | Inner_loss_B: 0.0623 | Inner_loss_F: 0.2685 | Inner_loss: 0.8916
# Model saved
# Step 1900 Pre-Adapt | Inner_loss_B: 10.0098 | Inner_loss_F: 0.1949 | Inner_loss: 100.2926
# Step 1900 Post-Adapt | Inner_loss_B: 0.0587 | Inner_loss_F: 0.2475 | Inner_loss: 0.8346
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 9.6551 | Inner_loss_F: 0.1552 | Inner_loss: 96.7060 | NRMSE: 0.7614
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0423 | Inner_loss_F: 0.2053 | Inner_loss: 0.6282 | NRMSE: 0.2514
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 12.6011 | Inner_loss_F: 2.7619 | Inner_loss: 128.7728 | NRMSE: 0.8134
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 3.2573 | Inner_loss_F: 2.4899 | Inner_loss: 35.0625 | NRMSE: 2.3561
# Step 1920 Pre-Adapt | Inner_loss_B: 9.9617 | Inner_loss_F: 0.1984 | Inner_loss: 99.8150
# Step 1920 Post-Adapt | Inner_loss_B: 0.0667 | Inner_loss_F: 0.2551 | Inner_loss: 0.9221
# Step 1940 Pre-Adapt | Inner_loss_B: 10.0036 | Inner_loss_F: 0.2177 | Inner_loss: 100.2538
# Step 1940 Post-Adapt | Inner_loss_B: 0.0343 | Inner_loss_F: 0.1688 | Inner_loss: 0.5116
# Step 1960 Pre-Adapt | Inner_loss_B: 9.8563 | Inner_loss_F: 0.1873 | Inner_loss: 98.7507
# Step 1960 Post-Adapt | Inner_loss_B: 0.0342 | Inner_loss_F: 0.2296 | Inner_loss: 0.5718
# Step 1980 Pre-Adapt | Inner_loss_B: 9.9819 | Inner_loss_F: 0.2322 | Inner_loss: 100.0507
# Step 1980 Post-Adapt | Inner_loss_B: 0.0315 | Inner_loss_F: 0.2927 | Inner_loss: 0.6079
# Model saved
# Step 2000 Pre-Adapt | Inner_loss_B: 9.8407 | Inner_loss_F: 0.1886 | Inner_loss: 98.5959
# Step 2000 Post-Adapt | Inner_loss_B: 0.0259 | Inner_loss_F: 0.1816 | Inner_loss: 0.4409
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 9.3101 | Inner_loss_F: 0.1708 | Inner_loss: 93.2723 | NRMSE: 0.7584
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0157 | Inner_loss_F: 0.1606 | Inner_loss: 0.3172 | NRMSE: 0.1697
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 12.4387 | Inner_loss_F: 2.3552 | Inner_loss: 126.7427 | NRMSE: 0.8131
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 1.7640 | Inner_loss_F: 2.5113 | Inner_loss: 20.1515 | NRMSE: 2.2067
# Step 2020 Pre-Adapt | Inner_loss_B: 9.6650 | Inner_loss_F: 0.1955 | Inner_loss: 96.8458
# Step 2020 Post-Adapt | Inner_loss_B: 0.0204 | Inner_loss_F: 0.1824 | Inner_loss: 0.3866
# Step 2040 Pre-Adapt | Inner_loss_B: 9.5800 | Inner_loss_F: 0.2321 | Inner_loss: 96.0318
# Step 2040 Post-Adapt | Inner_loss_B: 0.0172 | Inner_loss_F: 0.2106 | Inner_loss: 0.3825
# Step 2060 Pre-Adapt | Inner_loss_B: 9.4049 | Inner_loss_F: 0.1981 | Inner_loss: 94.2466
# Step 2060 Post-Adapt | Inner_loss_B: 0.0104 | Inner_loss_F: 0.2173 | Inner_loss: 0.3208
# Step 2080 Pre-Adapt | Inner_loss_B: 9.3780 | Inner_loss_F: 0.1986 | Inner_loss: 93.9788
# Step 2080 Post-Adapt | Inner_loss_B: 0.0108 | Inner_loss_F: 0.1563 | Inner_loss: 0.2642
# Model saved
# Step 2100 Pre-Adapt | Inner_loss_B: 9.0880 | Inner_loss_F: 0.2002 | Inner_loss: 91.0803
# Step 2100 Post-Adapt | Inner_loss_B: 0.0079 | Inner_loss_F: 0.2028 | Inner_loss: 0.2820
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 8.7402 | Inner_loss_F: 0.1574 | Inner_loss: 87.5598 | NRMSE: 0.7527
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0075 | Inner_loss_F: 0.1708 | Inner_loss: 0.2454 | NRMSE: 0.1305
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 11.9645 | Inner_loss_F: 2.1966 | Inner_loss: 121.8413 | NRMSE: 0.8103
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 1.0862 | Inner_loss_F: 2.5867 | Inner_loss: 13.4488 | NRMSE: 3.4577
# Step 2120 Pre-Adapt | Inner_loss_B: 8.8745 | Inner_loss_F: 0.2015 | Inner_loss: 88.9462
# Step 2120 Post-Adapt | Inner_loss_B: 0.0106 | Inner_loss_F: 0.1843 | Inner_loss: 0.2906
# Step 2140 Pre-Adapt | Inner_loss_B: 8.9135 | Inner_loss_F: 0.2324 | Inner_loss: 89.3675
# Step 2140 Post-Adapt | Inner_loss_B: 0.0151 | Inner_loss_F: 0.2034 | Inner_loss: 0.3541
# Step 2160 Pre-Adapt | Inner_loss_B: 8.5859 | Inner_loss_F: 0.2076 | Inner_loss: 86.0663
# Step 2160 Post-Adapt | Inner_loss_B: 0.0068 | Inner_loss_F: 0.1333 | Inner_loss: 0.2009
# Step 2180 Pre-Adapt | Inner_loss_B: 8.5130 | Inner_loss_F: 0.1861 | Inner_loss: 85.3163
# Step 2180 Post-Adapt | Inner_loss_B: 0.0096 | Inner_loss_F: 0.2135 | Inner_loss: 0.3098
# Model saved
# Step 2200 Pre-Adapt | Inner_loss_B: 8.3502 | Inner_loss_F: 0.2393 | Inner_loss: 83.7408
# Step 2200 Post-Adapt | Inner_loss_B: 0.0138 | Inner_loss_F: 0.2318 | Inner_loss: 0.3693
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 7.8748 | Inner_loss_F: 0.1456 | Inner_loss: 78.8938 | NRMSE: 0.7428
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0065 | Inner_loss_F: 0.1995 | Inner_loss: 0.2650 | NRMSE: 0.1293
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 11.0475 | Inner_loss_F: 2.1523 | Inner_loss: 112.6270 | NRMSE: 0.8031
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7586 | Inner_loss_F: 2.1655 | Inner_loss: 9.7517 | NRMSE: 3.7256
# Step 2220 Pre-Adapt | Inner_loss_B: 8.1440 | Inner_loss_F: 0.1843 | Inner_loss: 81.6243
# Step 2220 Post-Adapt | Inner_loss_B: 0.0082 | Inner_loss_F: 0.1653 | Inner_loss: 0.2471
# Step 2240 Pre-Adapt | Inner_loss_B: 7.7568 | Inner_loss_F: 0.2158 | Inner_loss: 77.7834
# Step 2240 Post-Adapt | Inner_loss_B: 0.0083 | Inner_loss_F: 0.1902 | Inner_loss: 0.2735
# Step 2260 Pre-Adapt | Inner_loss_B: 7.5152 | Inner_loss_F: 0.2045 | Inner_loss: 75.3563
# Step 2260 Post-Adapt | Inner_loss_B: 0.0089 | Inner_loss_F: 0.2023 | Inner_loss: 0.2917
# Step 2280 Pre-Adapt | Inner_loss_B: 7.3114 | Inner_loss_F: 0.2271 | Inner_loss: 73.3415
# Step 2280 Post-Adapt | Inner_loss_B: 0.0067 | Inner_loss_F: 0.1727 | Inner_loss: 0.2394
# Model saved
# Step 2300 Pre-Adapt | Inner_loss_B: 6.8864 | Inner_loss_F: 0.1653 | Inner_loss: 69.0290
# Step 2300 Post-Adapt | Inner_loss_B: 0.0089 | Inner_loss_F: 0.1822 | Inner_loss: 0.2714
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 6.6715 | Inner_loss_F: 0.1476 | Inner_loss: 66.8625 | NRMSE: 0.7261
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0066 | Inner_loss_F: 0.1669 | Inner_loss: 0.2334 | NRMSE: 0.1644
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 9.6010 | Inner_loss_F: 2.4756 | Inner_loss: 98.4855 | NRMSE: 0.7883
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.8272 | Inner_loss_F: 2.5312 | Inner_loss: 10.8036 | NRMSE: 3.1713
# Step 2320 Pre-Adapt | Inner_loss_B: 6.7495 | Inner_loss_F: 0.1787 | Inner_loss: 67.6741
# Step 2320 Post-Adapt | Inner_loss_B: 0.0060 | Inner_loss_F: 0.2251 | Inner_loss: 0.2847
# Step 2340 Pre-Adapt | Inner_loss_B: 6.2854 | Inner_loss_F: 0.1451 | Inner_loss: 62.9991
# Step 2340 Post-Adapt | Inner_loss_B: 0.0109 | Inner_loss_F: 0.2404 | Inner_loss: 0.3490
# Step 2360 Pre-Adapt | Inner_loss_B: 6.0585 | Inner_loss_F: 0.2064 | Inner_loss: 60.7917
# Step 2360 Post-Adapt | Inner_loss_B: 0.0107 | Inner_loss_F: 0.2519 | Inner_loss: 0.3585
# Step 2380 Pre-Adapt | Inner_loss_B: 5.0960 | Inner_loss_F: 0.1450 | Inner_loss: 51.1055
# Step 2380 Post-Adapt | Inner_loss_B: 0.0288 | Inner_loss_F: 0.2934 | Inner_loss: 0.5811
# Model saved
# Step 2400 Pre-Adapt | Inner_loss_B: 5.0009 | Inner_loss_F: 0.2234 | Inner_loss: 50.2320
# Step 2400 Post-Adapt | Inner_loss_B: 0.0611 | Inner_loss_F: 0.2861 | Inner_loss: 0.8968
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 4.4333 | Inner_loss_F: 0.1401 | Inner_loss: 44.4735 | NRMSE: 0.6797
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0467 | Inner_loss_F: 0.2842 | Inner_loss: 0.7514 | NRMSE: 0.2870
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 6.8254 | Inner_loss_F: 2.1567 | Inner_loss: 70.4102 | NRMSE: 0.7390
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 2.2249 | Inner_loss_F: 2.2705 | Inner_loss: 24.5198 | NRMSE: 4.6267
# Step 2420 Pre-Adapt | Inner_loss_B: 4.3642 | Inner_loss_F: 0.1813 | Inner_loss: 43.8233
# Step 2420 Post-Adapt | Inner_loss_B: 0.1488 | Inner_loss_F: 0.2724 | Inner_loss: 1.7602
# Step 2440 Pre-Adapt | Inner_loss_B: 3.4673 | Inner_loss_F: 0.2483 | Inner_loss: 34.9215
# Step 2440 Post-Adapt | Inner_loss_B: 0.1606 | Inner_loss_F: 0.3135 | Inner_loss: 1.9190
# Step 2460 Pre-Adapt | Inner_loss_B: 3.0143 | Inner_loss_F: 0.2644 | Inner_loss: 30.4074
# Step 2460 Post-Adapt | Inner_loss_B: 0.1457 | Inner_loss_F: 0.2662 | Inner_loss: 1.7236
# Step 2480 Pre-Adapt | Inner_loss_B: 2.9818 | Inner_loss_F: 0.3508 | Inner_loss: 30.1688
# Step 2480 Post-Adapt | Inner_loss_B: 0.1697 | Inner_loss_F: 0.1522 | Inner_loss: 1.8488
# Model saved
# Step 2500 Pre-Adapt | Inner_loss_B: 3.2540 | Inner_loss_F: 0.4274 | Inner_loss: 32.9672
# Step 2500 Post-Adapt | Inner_loss_B: 0.1712 | Inner_loss_F: 0.2112 | Inner_loss: 1.9228
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 2.8954 | Inner_loss_F: 0.5451 | Inner_loss: 29.4996 | NRMSE: 0.6130
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.2344 | Inner_loss_F: 0.1510 | Inner_loss: 2.4954 | NRMSE: 0.3495
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 4.7680 | Inner_loss_F: 2.3514 | Inner_loss: 50.0312 | NRMSE: 0.6274
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 2.1434 | Inner_loss_F: 2.6671 | Inner_loss: 24.1013 | NRMSE: 4.0535
# Step 2520 Pre-Adapt | Inner_loss_B: 4.0059 | Inner_loss_F: 0.3669 | Inner_loss: 40.4261
# Step 2520 Post-Adapt | Inner_loss_B: 0.4430 | Inner_loss_F: 0.2536 | Inner_loss: 4.6836
# Step 2540 Pre-Adapt | Inner_loss_B: 4.6853 | Inner_loss_F: 0.4375 | Inner_loss: 47.2907
# Step 2540 Post-Adapt | Inner_loss_B: 0.1970 | Inner_loss_F: 0.2316 | Inner_loss: 2.2020
# Step 2560 Pre-Adapt | Inner_loss_B: 4.9414 | Inner_loss_F: 0.5069 | Inner_loss: 49.9208
# Step 2560 Post-Adapt | Inner_loss_B: 0.2009 | Inner_loss_F: 0.2266 | Inner_loss: 2.2357
# Step 2580 Pre-Adapt | Inner_loss_B: 4.8508 | Inner_loss_F: 0.5381 | Inner_loss: 49.0458
# Step 2580 Post-Adapt | Inner_loss_B: 0.1717 | Inner_loss_F: 0.2211 | Inner_loss: 1.9380
# Model saved
# Step 2600 Pre-Adapt | Inner_loss_B: 4.6907 | Inner_loss_F: 0.5005 | Inner_loss: 47.4077
# Step 2600 Post-Adapt | Inner_loss_B: 0.1726 | Inner_loss_F: 0.2455 | Inner_loss: 1.9713
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 4.5747 | Inner_loss_F: 0.8305 | Inner_loss: 46.5771 | NRMSE: 0.6696
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.1151 | Inner_loss_F: 0.1753 | Inner_loss: 1.3262 | NRMSE: 0.3558
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 6.4469 | Inner_loss_F: 1.9159 | Inner_loss: 66.3850 | NRMSE: 0.6701
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 2.3659 | Inner_loss_F: 2.7328 | Inner_loss: 26.3917 | NRMSE: 5.7148
# Step 2620 Pre-Adapt | Inner_loss_B: 5.4855 | Inner_loss_F: 0.4172 | Inner_loss: 55.2720
# Step 2620 Post-Adapt | Inner_loss_B: 0.1344 | Inner_loss_F: 0.2223 | Inner_loss: 1.5661
# Step 2640 Pre-Adapt | Inner_loss_B: 5.2334 | Inner_loss_F: 0.6511 | Inner_loss: 52.9846
# Step 2640 Post-Adapt | Inner_loss_B: 0.1545 | Inner_loss_F: 0.2134 | Inner_loss: 1.7582
# Step 2660 Pre-Adapt | Inner_loss_B: 4.6269 | Inner_loss_F: 0.8415 | Inner_loss: 47.1104
# Step 2660 Post-Adapt | Inner_loss_B: 0.2377 | Inner_loss_F: 0.2328 | Inner_loss: 2.6102
# Step 2680 Pre-Adapt | Inner_loss_B: 5.0574 | Inner_loss_F: 0.6500 | Inner_loss: 51.2239
# Step 2680 Post-Adapt | Inner_loss_B: 0.1532 | Inner_loss_F: 0.1979 | Inner_loss: 1.7301
# Model saved
# Step 2700 Pre-Adapt | Inner_loss_B: 4.7136 | Inner_loss_F: 0.7900 | Inner_loss: 47.9262
# Step 2700 Post-Adapt | Inner_loss_B: 0.1434 | Inner_loss_F: 0.1932 | Inner_loss: 1.6267
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 4.3834 | Inner_loss_F: 0.8357 | Inner_loss: 44.6700 | NRMSE: 0.6533
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.1683 | Inner_loss_F: 0.1810 | Inner_loss: 1.8639 | NRMSE: 0.4823
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 6.4676 | Inner_loss_F: 2.7886 | Inner_loss: 67.4642 | NRMSE: 0.6490
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 2.2464 | Inner_loss_F: 2.5409 | Inner_loss: 25.0046 | NRMSE: 5.6216
# Step 2720 Pre-Adapt | Inner_loss_B: 4.6359 | Inner_loss_F: 0.8568 | Inner_loss: 47.2153
# Step 2720 Post-Adapt | Inner_loss_B: 0.1647 | Inner_loss_F: 0.1658 | Inner_loss: 1.8132
# Step 2740 Pre-Adapt | Inner_loss_B: 4.5331 | Inner_loss_F: 0.9441 | Inner_loss: 46.2750
# Step 2740 Post-Adapt | Inner_loss_B: 0.2347 | Inner_loss_F: 0.2386 | Inner_loss: 2.5859
# Step 2760 Pre-Adapt | Inner_loss_B: 4.3488 | Inner_loss_F: 1.1135 | Inner_loss: 44.6010
# Step 2760 Post-Adapt | Inner_loss_B: 0.3800 | Inner_loss_F: 0.1928 | Inner_loss: 3.9933
# Step 2780 Pre-Adapt | Inner_loss_B: 4.2607 | Inner_loss_F: 1.2497 | Inner_loss: 43.8564
# Step 2780 Post-Adapt | Inner_loss_B: 0.3924 | Inner_loss_F: 0.2362 | Inner_loss: 4.1601
# Model saved
# Step 2800 Pre-Adapt | Inner_loss_B: 3.9414 | Inner_loss_F: 1.4297 | Inner_loss: 40.8437
# Step 2800 Post-Adapt | Inner_loss_B: 0.4234 | Inner_loss_F: 0.2266 | Inner_loss: 4.4605
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 3.7552 | Inner_loss_F: 1.7831 | Inner_loss: 39.3348 | NRMSE: 0.6266
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.3591 | Inner_loss_F: 0.1774 | Inner_loss: 3.7684 | NRMSE: 0.8139
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 5.6206 | Inner_loss_F: 3.2650 | Inner_loss: 59.4711 | NRMSE: 0.6482
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 4.1325 | Inner_loss_F: 3.0888 | Inner_loss: 44.4143 | NRMSE: 3.8229
# Step 2820 Pre-Adapt | Inner_loss_B: 3.6841 | Inner_loss_F: 1.2845 | Inner_loss: 38.1254
# Step 2820 Post-Adapt | Inner_loss_B: 0.3559 | Inner_loss_F: 0.2156 | Inner_loss: 3.7749
# Step 2840 Pre-Adapt | Inner_loss_B: 3.6790 | Inner_loss_F: 1.2197 | Inner_loss: 38.0099
# Step 2840 Post-Adapt | Inner_loss_B: 0.6832 | Inner_loss_F: 0.2026 | Inner_loss: 7.0345
# Step 2860 Pre-Adapt | Inner_loss_B: 3.1158 | Inner_loss_F: 1.6159 | Inner_loss: 32.7738
# Step 2860 Post-Adapt | Inner_loss_B: 0.6311 | Inner_loss_F: 0.2142 | Inner_loss: 6.5253
# Step 2880 Pre-Adapt | Inner_loss_B: 3.2309 | Inner_loss_F: 0.9818 | Inner_loss: 33.2908
# Step 2880 Post-Adapt | Inner_loss_B: 0.6240 | Inner_loss_F: 0.2893 | Inner_loss: 6.5293
# Model saved
# Step 2900 Pre-Adapt | Inner_loss_B: 3.5827 | Inner_loss_F: 0.8643 | Inner_loss: 36.6913
# Step 2900 Post-Adapt | Inner_loss_B: 1.4532 | Inner_loss_F: 0.2128 | Inner_loss: 14.7446
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 3.5359 | Inner_loss_F: 0.8852 | Inner_loss: 36.2446 | NRMSE: 0.6262
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.8770 | Inner_loss_F: 0.1472 | Inner_loss: 8.9177 | NRMSE: 0.9934
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 5.2220 | Inner_loss_F: 1.9873 | Inner_loss: 54.2074 | NRMSE: 0.6368
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 3.8713 | Inner_loss_F: 2.7073 | Inner_loss: 41.4204 | NRMSE: 2.8240
# Step 2920 Pre-Adapt | Inner_loss_B: 4.6566 | Inner_loss_F: 0.6222 | Inner_loss: 47.1881
# Step 2920 Post-Adapt | Inner_loss_B: 0.7500 | Inner_loss_F: 0.2177 | Inner_loss: 7.7182
# Step 2940 Pre-Adapt | Inner_loss_B: 5.6185 | Inner_loss_F: 0.3898 | Inner_loss: 56.5749
# Step 2940 Post-Adapt | Inner_loss_B: 0.2701 | Inner_loss_F: 0.1864 | Inner_loss: 2.8872
# Step 2960 Pre-Adapt | Inner_loss_B: 5.4903 | Inner_loss_F: 0.4314 | Inner_loss: 55.3347
# Step 2960 Post-Adapt | Inner_loss_B: 0.3470 | Inner_loss_F: 0.1764 | Inner_loss: 3.6461
# Step 2980 Pre-Adapt | Inner_loss_B: 6.1547 | Inner_loss_F: 0.3249 | Inner_loss: 61.8717
# Step 2980 Post-Adapt | Inner_loss_B: 0.2585 | Inner_loss_F: 0.2182 | Inner_loss: 2.8027
# Model saved
# Step 3000 Pre-Adapt | Inner_loss_B: 6.1950 | Inner_loss_F: 0.3622 | Inner_loss: 62.3124
# Step 3000 Post-Adapt | Inner_loss_B: 0.2689 | Inner_loss_F: 0.2579 | Inner_loss: 2.9466
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 5.8334 | Inner_loss_F: 0.4084 | Inner_loss: 58.7427 | NRMSE: 0.7039
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.2310 | Inner_loss_F: 0.1410 | Inner_loss: 2.4512 | NRMSE: 0.5748
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 6.5925 | Inner_loss_F: 1.6944 | Inner_loss: 67.6199 | NRMSE: 0.7202
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 5.7983 | Inner_loss_F: 2.6359 | Inner_loss: 60.6188 | NRMSE: 5.3331
# Step 3020 Pre-Adapt | Inner_loss_B: 6.1272 | Inner_loss_F: 0.2480 | Inner_loss: 61.5204
# Step 3020 Post-Adapt | Inner_loss_B: 0.2662 | Inner_loss_F: 0.2292 | Inner_loss: 2.8914
# Step 3040 Pre-Adapt | Inner_loss_B: 6.2602 | Inner_loss_F: 0.2693 | Inner_loss: 62.8712
# Step 3040 Post-Adapt | Inner_loss_B: 0.1962 | Inner_loss_F: 0.2476 | Inner_loss: 2.2091
# Step 3060 Pre-Adapt | Inner_loss_B: 6.3824 | Inner_loss_F: 0.2581 | Inner_loss: 64.0821
# Step 3060 Post-Adapt | Inner_loss_B: 0.1710 | Inner_loss_F: 0.2577 | Inner_loss: 1.9676
# Step 3080 Pre-Adapt | Inner_loss_B: 6.0213 | Inner_loss_F: 0.2786 | Inner_loss: 60.4914
# Step 3080 Post-Adapt | Inner_loss_B: 0.1606 | Inner_loss_F: 0.2052 | Inner_loss: 1.8109
# Model saved
# Step 3100 Pre-Adapt | Inner_loss_B: 6.1208 | Inner_loss_F: 0.2522 | Inner_loss: 61.4604
# Step 3100 Post-Adapt | Inner_loss_B: 0.1660 | Inner_loss_F: 0.2152 | Inner_loss: 1.8750
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 5.7982 | Inner_loss_F: 0.2511 | Inner_loss: 58.2327 | NRMSE: 0.7067
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.1488 | Inner_loss_F: 0.1690 | Inner_loss: 1.6571 | NRMSE: 0.2921
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 6.1903 | Inner_loss_F: 1.9479 | Inner_loss: 63.8510 | NRMSE: 0.7207
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 2.7916 | Inner_loss_F: 2.6105 | Inner_loss: 30.5260 | NRMSE: 3.7063
# Step 3120 Pre-Adapt | Inner_loss_B: 6.1226 | Inner_loss_F: 0.2790 | Inner_loss: 61.5047
# Step 3120 Post-Adapt | Inner_loss_B: 0.0939 | Inner_loss_F: 0.2155 | Inner_loss: 1.1541
# Step 3140 Pre-Adapt | Inner_loss_B: 5.7345 | Inner_loss_F: 0.3067 | Inner_loss: 57.6520
# Step 3140 Post-Adapt | Inner_loss_B: 0.0857 | Inner_loss_F: 0.2440 | Inner_loss: 1.1006
# Step 3160 Pre-Adapt | Inner_loss_B: 5.5122 | Inner_loss_F: 0.2535 | Inner_loss: 55.3756
# Step 3160 Post-Adapt | Inner_loss_B: 0.0748 | Inner_loss_F: 0.2134 | Inner_loss: 0.9615
# Step 3180 Pre-Adapt | Inner_loss_B: 5.4246 | Inner_loss_F: 0.2619 | Inner_loss: 54.5081
# Step 3180 Post-Adapt | Inner_loss_B: 0.0650 | Inner_loss_F: 0.2366 | Inner_loss: 0.8864
# Model saved
# Step 3200 Pre-Adapt | Inner_loss_B: 5.2718 | Inner_loss_F: 0.2855 | Inner_loss: 53.0034
# Step 3200 Post-Adapt | Inner_loss_B: 0.0539 | Inner_loss_F: 0.1748 | Inner_loss: 0.7134
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 4.9715 | Inner_loss_F: 0.3619 | Inner_loss: 50.0771 | NRMSE: 0.6883
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0588 | Inner_loss_F: 0.1862 | Inner_loss: 0.7740 | NRMSE: 0.2894
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 5.4513 | Inner_loss_F: 2.2187 | Inner_loss: 56.7313 | NRMSE: 0.7010
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.8070 | Inner_loss_F: 2.1412 | Inner_loss: 10.2112 | NRMSE: 6.2694
# Step 3220 Pre-Adapt | Inner_loss_B: 5.0909 | Inner_loss_F: 0.3356 | Inner_loss: 51.2444
# Step 3220 Post-Adapt | Inner_loss_B: 0.0305 | Inner_loss_F: 0.1593 | Inner_loss: 0.4643
# Step 3240 Pre-Adapt | Inner_loss_B: 4.8038 | Inner_loss_F: 0.3548 | Inner_loss: 48.3932
# Step 3240 Post-Adapt | Inner_loss_B: 0.0402 | Inner_loss_F: 0.2176 | Inner_loss: 0.6192
# Step 3260 Pre-Adapt | Inner_loss_B: 4.4624 | Inner_loss_F: 0.3949 | Inner_loss: 45.0187
# Step 3260 Post-Adapt | Inner_loss_B: 0.0411 | Inner_loss_F: 0.2512 | Inner_loss: 0.6625
# Step 3280 Pre-Adapt | Inner_loss_B: 4.0086 | Inner_loss_F: 0.4098 | Inner_loss: 40.4960
# Step 3280 Post-Adapt | Inner_loss_B: 0.0426 | Inner_loss_F: 0.2027 | Inner_loss: 0.6284
# Model saved
# ...
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.4777 | Inner_loss_F: 2.2639 | Inner_loss: 7.0407 | NRMSE: 1.2529
# Step 3920 Pre-Adapt | Inner_loss_B: 0.0625 | Inner_loss_F: 0.3426 | Inner_loss: 0.9673
# Step 3920 Post-Adapt | Inner_loss_B: 0.0261 | Inner_loss_F: 0.1358 | Inner_loss: 0.3972
# Step 3940 Pre-Adapt | Inner_loss_B: 0.0641 | Inner_loss_F: 0.1948 | Inner_loss: 0.8357
# Step 3940 Post-Adapt | Inner_loss_B: 0.0024 | Inner_loss_F: 0.0951 | Inner_loss: 0.1192
# Step 3960 Pre-Adapt | Inner_loss_B: 0.0354 | Inner_loss_F: 0.2259 | Inner_loss: 0.5803
# Step 3960 Post-Adapt | Inner_loss_B: 0.0066 | Inner_loss_F: 0.0967 | Inner_loss: 0.1625
# Step 3980 Pre-Adapt | Inner_loss_B: 0.0223 | Inner_loss_F: 0.2516 | Inner_loss: 0.4746
# Step 3980 Post-Adapt | Inner_loss_B: 0.0050 | Inner_loss_F: 0.1259 | Inner_loss: 0.1754
# Model saved
# Step 4000 Pre-Adapt | Inner_loss_B: 0.0163 | Inner_loss_F: 0.1942 | Inner_loss: 0.3571
# Step 4000 Post-Adapt | Inner_loss_B: 0.0058 | Inner_loss_F: 0.1069 | Inner_loss: 0.1651
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.0142 | Inner_loss_F: 0.1710 | Inner_loss: 0.3128 | NRMSE: 0.1257
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0028 | Inner_loss_F: 0.0955 | Inner_loss: 0.1236 | NRMSE: 0.1227
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2880 | Inner_loss_F: 2.3811 | Inner_loss: 5.2613 | NRMSE: 0.4646
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2144 | Inner_loss_F: 1.6578 | Inner_loss: 3.8017 | NRMSE: 1.5287
# Step 4020 Pre-Adapt | Inner_loss_B: 0.0167 | Inner_loss_F: 0.2065 | Inner_loss: 0.3736
# Step 4020 Post-Adapt | Inner_loss_B: 0.0091 | Inner_loss_F: 0.1344 | Inner_loss: 0.2255
# Step 4040 Pre-Adapt | Inner_loss_B: 0.0169 | Inner_loss_F: 0.1581 | Inner_loss: 0.3273
# Step 4040 Post-Adapt | Inner_loss_B: 0.0055 | Inner_loss_F: 0.0864 | Inner_loss: 0.1415
# Step 4060 Pre-Adapt | Inner_loss_B: 0.0343 | Inner_loss_F: 0.1894 | Inner_loss: 0.5321
# Step 4060 Post-Adapt | Inner_loss_B: 0.0054 | Inner_loss_F: 0.1063 | Inner_loss: 0.1601
# Step 4080 Pre-Adapt | Inner_loss_B: 0.0566 | Inner_loss_F: 0.1755 | Inner_loss: 0.7414
# Step 4080 Post-Adapt | Inner_loss_B: 0.0061 | Inner_loss_F: 0.1083 | Inner_loss: 0.1691
# Model saved
# Step 4100 Pre-Adapt | Inner_loss_B: 0.0935 | Inner_loss_F: 0.2165 | Inner_loss: 1.1514
# Step 4100 Post-Adapt | Inner_loss_B: 0.0085 | Inner_loss_F: 0.1357 | Inner_loss: 0.2210
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.0876 | Inner_loss_F: 0.1216 | Inner_loss: 0.9981 | NRMSE: 0.2073
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0074 | Inner_loss_F: 0.0826 | Inner_loss: 0.1570 | NRMSE: 0.1638
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.4619 | Inner_loss_F: 1.9176 | Inner_loss: 6.5367 | NRMSE: 0.3364
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.1213 | Inner_loss_F: 1.5253 | Inner_loss: 2.7382 | NRMSE: 1.2478
# Step 4120 Pre-Adapt | Inner_loss_B: 0.1144 | Inner_loss_F: 0.1492 | Inner_loss: 1.2931
# Step 4120 Post-Adapt | Inner_loss_B: 0.0100 | Inner_loss_F: 0.0964 | Inner_loss: 0.1961
# Step 4140 Pre-Adapt | Inner_loss_B: 0.1499 | Inner_loss_F: 0.1869 | Inner_loss: 1.6856
# Step 4140 Post-Adapt | Inner_loss_B: 0.0105 | Inner_loss_F: 0.1185 | Inner_loss: 0.2238
# Step 4160 Pre-Adapt | Inner_loss_B: 0.1629 | Inner_loss_F: 0.1991 | Inner_loss: 1.8279
# Step 4160 Post-Adapt | Inner_loss_B: 0.0099 | Inner_loss_F: 0.1079 | Inner_loss: 0.2065
# Step 4180 Pre-Adapt | Inner_loss_B: 0.1952 | Inner_loss_F: 0.1598 | Inner_loss: 2.1117
# Step 4180 Post-Adapt | Inner_loss_B: 0.0097 | Inner_loss_F: 0.0942 | Inner_loss: 0.1914
# Model saved
# Step 4200 Pre-Adapt | Inner_loss_B: 0.2449 | Inner_loss_F: 0.1655 | Inner_loss: 2.6146
# Step 4200 Post-Adapt | Inner_loss_B: 0.0082 | Inner_loss_F: 0.1174 | Inner_loss: 0.1989
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.2328 | Inner_loss_F: 0.1813 | Inner_loss: 2.5097 | NRMSE: 0.3247
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0120 | Inner_loss_F: 0.0965 | Inner_loss: 0.2169 | NRMSE: 0.1783
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.5464 | Inner_loss_F: 1.8300 | Inner_loss: 7.2936 | NRMSE: 0.3230
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.0703 | Inner_loss_F: 1.4813 | Inner_loss: 2.1843 | NRMSE: 1.2273
# Step 4220 Pre-Adapt | Inner_loss_B: 0.2730 | Inner_loss_F: 0.2016 | Inner_loss: 2.9321
# Step 4220 Post-Adapt | Inner_loss_B: 0.0119 | Inner_loss_F: 0.0946 | Inner_loss: 0.2134
# Step 4240 Pre-Adapt | Inner_loss_B: 0.3267 | Inner_loss_F: 0.2703 | Inner_loss: 3.5376
# Step 4240 Post-Adapt | Inner_loss_B: 0.0149 | Inner_loss_F: 0.1388 | Inner_loss: 0.2878
# Step 4260 Pre-Adapt | Inner_loss_B: 0.3940 | Inner_loss_F: 0.2579 | Inner_loss: 4.1981
# Step 4260 Post-Adapt | Inner_loss_B: 0.0104 | Inner_loss_F: 0.1150 | Inner_loss: 0.2192
# Step 4280 Pre-Adapt | Inner_loss_B: 0.4497 | Inner_loss_F: 0.2959 | Inner_loss: 4.7931
# Step 4280 Post-Adapt | Inner_loss_B: 0.0111 | Inner_loss_F: 0.1369 | Inner_loss: 0.2483
# Model saved
# Step 4300 Pre-Adapt | Inner_loss_B: 0.4997 | Inner_loss_F: 0.3181 | Inner_loss: 5.3150
# Step 4300 Post-Adapt | Inner_loss_B: 0.0149 | Inner_loss_F: 0.1087 | Inner_loss: 0.2581
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.5000 | Inner_loss_F: 0.3643 | Inner_loss: 5.3647 | NRMSE: 0.4220
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0146 | Inner_loss_F: 0.1004 | Inner_loss: 0.2462 | NRMSE: 0.1533
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.6689 | Inner_loss_F: 1.5760 | Inner_loss: 8.2649 | NRMSE: 0.3388
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.0855 | Inner_loss_F: 1.6413 | Inner_loss: 2.4965 | NRMSE: 1.0461
# Step 4320 Pre-Adapt | Inner_loss_B: 0.5486 | Inner_loss_F: 0.4394 | Inner_loss: 5.9249
# Step 4320 Post-Adapt | Inner_loss_B: 0.0188 | Inner_loss_F: 0.1169 | Inner_loss: 0.3046
# Step 4340 Pre-Adapt | Inner_loss_B: 0.5795 | Inner_loss_F: 0.5932 | Inner_loss: 6.3881
# Step 4340 Post-Adapt | Inner_loss_B: 0.0178 | Inner_loss_F: 0.1222 | Inner_loss: 0.3003
# Step 4360 Pre-Adapt | Inner_loss_B: 0.6016 | Inner_loss_F: 0.8741 | Inner_loss: 6.8906
# Step 4360 Post-Adapt | Inner_loss_B: 0.0234 | Inner_loss_F: 0.1378 | Inner_loss: 0.3722
# Step 4380 Pre-Adapt | Inner_loss_B: 0.6548 | Inner_loss_F: 0.9190 | Inner_loss: 7.4666
# Step 4380 Post-Adapt | Inner_loss_B: 0.0200 | Inner_loss_F: 0.1244 | Inner_loss: 0.3240
# Model saved
# Step 4400 Pre-Adapt | Inner_loss_B: 0.7309 | Inner_loss_F: 0.9928 | Inner_loss: 8.3016
# Step 4400 Post-Adapt | Inner_loss_B: 0.0210 | Inner_loss_F: 0.1113 | Inner_loss: 0.3209
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 0.6970 | Inner_loss_F: 0.7113 | Inner_loss: 7.6811 | NRMSE: 0.4494
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0203 | Inner_loss_F: 0.0837 | Inner_loss: 0.2870 | NRMSE: 0.1620
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7312 | Inner_loss_F: 1.9798 | Inner_loss: 9.2917 | NRMSE: 0.4178
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.2351 | Inner_loss_F: 1.4328 | Inner_loss: 3.7838 | NRMSE: 1.5076
# Step 4420 Pre-Adapt | Inner_loss_B: 0.8134 | Inner_loss_F: 1.0825 | Inner_loss: 9.2167
# Step 4420 Post-Adapt | Inner_loss_B: 0.0295 | Inner_loss_F: 0.1272 | Inner_loss: 0.4224
# Step 4440 Pre-Adapt | Inner_loss_B: 1.0409 | Inner_loss_F: 1.8688 | Inner_loss: 12.2782
# Step 4440 Post-Adapt | Inner_loss_B: 0.0547 | Inner_loss_F: 0.1141 | Inner_loss: 0.6612
# Step 4460 Pre-Adapt | Inner_loss_B: 1.3506 | Inner_loss_F: 1.9761 | Inner_loss: 15.4824
# Step 4460 Post-Adapt | Inner_loss_B: 0.0494 | Inner_loss_F: 0.1352 | Inner_loss: 0.6289
# Step 4480 Pre-Adapt | Inner_loss_B: 1.6762 | Inner_loss_F: 3.2562 | Inner_loss: 20.0182
# Step 4480 Post-Adapt | Inner_loss_B: 0.0768 | Inner_loss_F: 0.2111 | Inner_loss: 0.9792
# Model saved
# Step 4500 Pre-Adapt | Inner_loss_B: 2.0727 | Inner_loss_F: 2.4157 | Inner_loss: 23.1431
# Step 4500 Post-Adapt | Inner_loss_B: 0.0790 | Inner_loss_F: 0.1948 | Inner_loss: 0.9847
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 1.9738 | Inner_loss_F: 2.9169 | Inner_loss: 22.6546 | NRMSE: 0.5942
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0956 | Inner_loss_F: 0.1785 | Inner_loss: 1.1347 | NRMSE: 0.2511
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 1.6984 | Inner_loss_F: 4.7510 | Inner_loss: 21.7355 | NRMSE: 0.6166
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.6987 | Inner_loss_F: 2.5280 | Inner_loss: 9.5153 | NRMSE: 2.8763
# Step 4520 Pre-Adapt | Inner_loss_B: 2.4156 | Inner_loss_F: 5.2358 | Inner_loss: 29.3919
# Step 4520 Post-Adapt | Inner_loss_B: 0.1123 | Inner_loss_F: 0.1681 | Inner_loss: 1.2915
# Step 4540 Pre-Adapt | Inner_loss_B: 2.2878 | Inner_loss_F: 4.4888 | Inner_loss: 27.3664
# Step 4540 Post-Adapt | Inner_loss_B: 0.1143 | Inner_loss_F: 0.1887 | Inner_loss: 1.3318
# Step 4560 Pre-Adapt | Inner_loss_B: 2.5152 | Inner_loss_F: 5.6059 | Inner_loss: 30.7582
# Step 4560 Post-Adapt | Inner_loss_B: 0.1281 | Inner_loss_F: 0.2077 | Inner_loss: 1.4886
# Step 4580 Pre-Adapt | Inner_loss_B: 2.5876 | Inner_loss_F: 6.0423 | Inner_loss: 31.9186
# Step 4580 Post-Adapt | Inner_loss_B: 0.1277 | Inner_loss_F: 0.1765 | Inner_loss: 1.4539
# Model saved
# Step 4600 Pre-Adapt | Inner_loss_B: 2.6748 | Inner_loss_F: 5.9368 | Inner_loss: 32.6852
# Step 4600 Post-Adapt | Inner_loss_B: 0.1348 | Inner_loss_F: 0.1844 | Inner_loss: 1.5328
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 2.5019 | Inner_loss_F: 3.7135 | Inner_loss: 28.7328 | NRMSE: 0.6247
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.1228 | Inner_loss_F: 0.1691 | Inner_loss: 1.3967 | NRMSE: 0.2983
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 2.1939 | Inner_loss_F: 4.6226 | Inner_loss: 26.5617 | NRMSE: 0.6160
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7790 | Inner_loss_F: 2.8068 | Inner_loss: 10.5967 | NRMSE: 2.8833
# Step 4620 Pre-Adapt | Inner_loss_B: 2.7216 | Inner_loss_F: 5.4400 | Inner_loss: 32.6559
# Step 4620 Post-Adapt | Inner_loss_B: 0.1694 | Inner_loss_F: 0.2029 | Inner_loss: 1.8969
# Step 4640 Pre-Adapt | Inner_loss_B: 2.7672 | Inner_loss_F: 6.6649 | Inner_loss: 34.3371
# Step 4640 Post-Adapt | Inner_loss_B: 0.1479 | Inner_loss_F: 0.2116 | Inner_loss: 1.6903
# Step 4660 Pre-Adapt | Inner_loss_B: 2.8469 | Inner_loss_F: 4.2193 | Inner_loss: 32.6880
# Step 4660 Post-Adapt | Inner_loss_B: 0.1502 | Inner_loss_F: 0.2470 | Inner_loss: 1.7489
# Step 4680 Pre-Adapt | Inner_loss_B: 3.0857 | Inner_loss_F: 3.5077 | Inner_loss: 34.3651
# Step 4680 Post-Adapt | Inner_loss_B: 0.1276 | Inner_loss_F: 0.2312 | Inner_loss: 1.5068
# Model saved
# Step 4700 Pre-Adapt | Inner_loss_B: 3.1543 | Inner_loss_F: 4.7295 | Inner_loss: 36.2720
# Step 4700 Post-Adapt | Inner_loss_B: 0.1286 | Inner_loss_F: 0.2229 | Inner_loss: 1.5091
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 3.1583 | Inner_loss_F: 4.1188 | Inner_loss: 35.7022 | NRMSE: 0.6535
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.1175 | Inner_loss_F: 0.1779 | Inner_loss: 1.3534 | NRMSE: 0.2778
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 2.8063 | Inner_loss_F: 6.1961 | Inner_loss: 34.2592 | NRMSE: 0.6053
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7369 | Inner_loss_F: 2.1648 | Inner_loss: 9.5343 | NRMSE: 3.4825
# Step 4720 Pre-Adapt | Inner_loss_B: 3.3126 | Inner_loss_F: 5.3386 | Inner_loss: 38.4644
# Step 4720 Post-Adapt | Inner_loss_B: 0.1164 | Inner_loss_F: 0.1511 | Inner_loss: 1.3149
# Step 4740 Pre-Adapt | Inner_loss_B: 3.4345 | Inner_loss_F: 4.2151 | Inner_loss: 38.5597
# Step 4740 Post-Adapt | Inner_loss_B: 0.1448 | Inner_loss_F: 0.2107 | Inner_loss: 1.6589
# Step 4760 Pre-Adapt | Inner_loss_B: 3.5039 | Inner_loss_F: 5.7766 | Inner_loss: 40.8161
# Step 4760 Post-Adapt | Inner_loss_B: 0.1412 | Inner_loss_F: 0.1993 | Inner_loss: 1.6112
# Step 4780 Pre-Adapt | Inner_loss_B: 3.6400 | Inner_loss_F: 6.2555 | Inner_loss: 42.6558
# Step 4780 Post-Adapt | Inner_loss_B: 0.1475 | Inner_loss_F: 0.2039 | Inner_loss: 1.6792
# Model saved
# Step 4800 Pre-Adapt | Inner_loss_B: 3.8311 | Inner_loss_F: 4.5293 | Inner_loss: 42.8398
# Step 4800 Post-Adapt | Inner_loss_B: 0.1350 | Inner_loss_F: 0.2031 | Inner_loss: 1.5533
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 3.8037 | Inner_loss_F: 3.1474 | Inner_loss: 41.1843 | NRMSE: 0.6773
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.1372 | Inner_loss_F: 0.1865 | Inner_loss: 1.5585 | NRMSE: 0.2854
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 3.2633 | Inner_loss_F: 5.0971 | Inner_loss: 37.7304 | NRMSE: 0.6062
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7457 | Inner_loss_F: 2.4927 | Inner_loss: 9.9500 | NRMSE: 4.0256
# Step 4820 Pre-Adapt | Inner_loss_B: 3.8753 | Inner_loss_F: 4.2008 | Inner_loss: 42.9542
# Step 4820 Post-Adapt | Inner_loss_B: 0.1322 | Inner_loss_F: 0.2029 | Inner_loss: 1.5253
# Step 4840 Pre-Adapt | Inner_loss_B: 3.8459 | Inner_loss_F: 3.4793 | Inner_loss: 41.9382
# Step 4840 Post-Adapt | Inner_loss_B: 0.1211 | Inner_loss_F: 0.2072 | Inner_loss: 1.4181
# Step 4860 Pre-Adapt | Inner_loss_B: 3.6901 | Inner_loss_F: 3.8248 | Inner_loss: 40.7253
# Step 4860 Post-Adapt | Inner_loss_B: 0.1033 | Inner_loss_F: 0.1971 | Inner_loss: 1.2297
# Step 4880 Pre-Adapt | Inner_loss_B: 3.8035 | Inner_loss_F: 3.3734 | Inner_loss: 41.4081
# Step 4880 Post-Adapt | Inner_loss_B: 0.1300 | Inner_loss_F: 0.2436 | Inner_loss: 1.5439
# Model saved
# Step 4900 Pre-Adapt | Inner_loss_B: 3.7754 | Inner_loss_F: 3.7266 | Inner_loss: 41.4808
# Step 4900 Post-Adapt | Inner_loss_B: 0.1126 | Inner_loss_F: 0.1910 | Inner_loss: 1.3166
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 3.7774 | Inner_loss_F: 3.0056 | Inner_loss: 40.7797 | NRMSE: 0.6769
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0958 | Inner_loss_F: 0.1916 | Inner_loss: 1.1492 | NRMSE: 0.2721
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 3.2299 | Inner_loss_F: 3.2432 | Inner_loss: 35.5423 | NRMSE: 0.6023
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7959 | Inner_loss_F: 2.2955 | Inner_loss: 10.2544 | NRMSE: 5.6707
# Step 4920 Pre-Adapt | Inner_loss_B: 3.6761 | Inner_loss_F: 2.6280 | Inner_loss: 39.3893
# Step 4920 Post-Adapt | Inner_loss_B: 0.1129 | Inner_loss_F: 0.2369 | Inner_loss: 1.3664
# Step 4940 Pre-Adapt | Inner_loss_B: 3.6874 | Inner_loss_F: 3.2893 | Inner_loss: 40.1632
# Step 4940 Post-Adapt | Inner_loss_B: 0.1062 | Inner_loss_F: 0.2171 | Inner_loss: 1.2788
# Step 4960 Pre-Adapt | Inner_loss_B: 3.6429 | Inner_loss_F: 2.2199 | Inner_loss: 38.6491
# Step 4960 Post-Adapt | Inner_loss_B: 0.1194 | Inner_loss_F: 0.2284 | Inner_loss: 1.4223
# Step 4980 Pre-Adapt | Inner_loss_B: 3.5699 | Inner_loss_F: 1.9960 | Inner_loss: 37.6946
# Step 4980 Post-Adapt | Inner_loss_B: 0.0825 | Inner_loss_F: 0.2075 | Inner_loss: 1.0322
# Model saved
# Step 5000 Pre-Adapt | Inner_loss_B: 3.3584 | Inner_loss_F: 2.7609 | Inner_loss: 36.3446
# Step 5000 Post-Adapt | Inner_loss_B: 0.0840 | Inner_loss_F: 0.1448 | Inner_loss: 0.9853
# Validation before training Pre-Adapt(0.336, -0.451)| Inner_loss_B: 3.3464 | Inner_loss_F: 1.7246 | Inner_loss: 35.1888 | NRMSE: 0.6618
# Validation before training Post-Adapt(0.336, -0.451)| Inner_loss_B: 0.0788 | Inner_loss_F: 0.2071 | Inner_loss: 0.9948 | NRMSE: 0.2352
# Validation OOD before training Pre-Adapt(-1.231, -1.046) | Inner_loss_B: 2.9497 | Inner_loss_F: 3.9646 | Inner_loss: 33.4612 | NRMSE: 0.5870
# Validation OOD before training Post-Adapt(-1.231, -1.046) | Inner_loss_B: 0.7153 | Inner_loss_F: 1.8809 | Inner_loss: 9.0340 | NRMSE: 6.3924

# %%
import pandas as pd

nrmse_df = pd.DataFrame(nrmse)
val_loss_df = pd.DataFrame(val_loss)
val_ood_loss_df = pd.DataFrame(val_ood_loss)
train_loss_df = pd.DataFrame(train_loss)

nrmse_df.to_csv('data/nrmse_poisson_high1_zs_maml.csv')
val_loss_df.to_csv('data/val_loss_poisson_high1_zs_maml.csv')
val_ood_loss_df.to_csv('data/val_ood_loss_poisson_high1_zs_maml.csv')
train_loss_df.to_csv('data/train_loss_poisson_high1_zs_maml.csv')

# %%
data_len = len(val_loss_df['inner_loss'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(val_loss_df['inner_loss']), label='loss')
plt.plot(x, np.array(val_loss_df['inner_loss_f']), label='loss_f')
plt.plot(x, np.array(val_loss_df['inner_loss_b']) * 10, label='loss_b')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Post-adapt validation losses (in-distribution)')
# Out:
# Text(0.5, 1.0, 'Post-adapt validation losses (in-distribution)')

# %%
data_len = len(val_loss_df['inner_loss'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(val_loss_df['inner_loss_pre_adapt']), label='loss')
plt.plot(x, np.array(val_loss_df['inner_loss_f_pre_adapt']), label='loss_f')
plt.plot(x, np.array(val_loss_df['inner_loss_b_pre_adapt']) * 10, label='loss_b')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Pre-adapt validation losses (in-distribution)')
# Out:
# Text(0.5, 1.0, 'Pre-adapt validation losses (in-distribution)')

# %%
data_len = len(val_loss_df['inner_loss'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(val_ood_loss_df['inner_loss']), label='loss')
plt.plot(x, np.array(val_ood_loss_df['inner_loss_f']), label='loss_f')
plt.plot(x, np.array(val_ood_loss_df['inner_loss_b']) * 10, label='loss_b')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.legend()
plt.title('Post-adapt validation losses (out-of-distribution)')
# Out:
# Text(0.5, 1.0, 'Post-adapt validation losses (out-of-distribution)')

# %%
data_len = len(val_loss_df['inner_loss'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(val_ood_loss_df['inner_loss_pre_adapt']), label='loss')
plt.plot(x, np.array(val_ood_loss_df['inner_loss_f_pre_adapt']), label='loss_f')
plt.plot(x, np.array(val_ood_loss_df['inner_loss_b_pre_adapt']) * 10, label='loss_b')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Pre-adapt validation losses (out-of-distribution)')
# Out:
# Text(0.5, 1.0, 'Pre-adapt validation losses (out-of-distribution)')

# %%
data_len = len(val_loss_df['inner_loss'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(val_loss_df['inner_loss_pre_adapt']), label='pre-adapt')
plt.plot(x, np.array(val_loss_df['inner_loss']), label='post-adapt')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Pre-adapt vs post-adapt validation losses (in-distribution)')
# Out:
# Text(0.5, 1.0, 'Pre-adapt vs post-adapt validation losses (in-distribution)')

# %%
data_len = len(val_loss_df['inner_loss'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(val_ood_loss_df['inner_loss_pre_adapt']), label='pre-adapt')
plt.plot(x, np.array(val_ood_loss_df['inner_loss']), label='post-adapt')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.yscale('log')
plt.title('Pre-adapt vs post-adapt validation losses (out-of-distribution)')
# Out:
# Text(0.5, 1.0, 'Pre-adapt vs post-adapt validation losses (out-of-distribution)')

# %%
data_len = len(nrmse['nrmse_val'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(nrmse['nrmse_val_pre_adapt']), label='pre-adapt')
plt.plot(x, np.array(nrmse['nrmse_val']), label='post-adapt')
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('NRMSE')
plt.legend()
plt.title('Validation metrics (out-of-distribution)')
# Out:
# Text(0.5, 1.0, 'Validation metrics (out-of-distribution)')

# %%
data_len = len(nrmse['nrmse_val'])
x = np.array([i * 5000 / data_len for i in range(data_len)])
plt.plot(x, np.array(nrmse['nrmse_val_ood_pre_adapt']), label='pre-adapt')
plt.plot(x, np.array(nrmse['nrmse_val_ood']), label='post-adapt')
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('NRMSE')
plt.legend()
plt.title('Validation metrics (out-of-distribution)')
# Out:
# Text(0.5, 1.0, 'Validation metrics (out-of-distribution)')

# %%
x = np.arange(4)
methods = ['PINN', 'zero-shot', 'MAML', 'adapted MAML']
values = [0.006841598904306745, 0.017072844474532906, 0.649507876627482, 0.13184379901471588]
colors = ['r', 'b', 'g', 'y']

plt.bar(x, values, color=colors)
plt.xticks(x, methods)
plt.yscale('log')
plt.ylabel('NRMSE')
plt.title('NRMSEs')

plt.show()

# %%
model = PINN(20, 5, dim=1, param_num=2, zero_shot=True)
model.load_state_dict(torch.load('models/maml_poisson_high1_4000.data'))
model.to(device)
# Out:
# PINN(
#   (module1): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Linear(in_features=20, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=20, bias=True)
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Current device:", device)
test_x = np.linspace(-1, 1, num=100).reshape(-1, 1)
# test_alpha = np.full((100, 1), alpha[2])
# test_beta = np.full((100, 1), beta[2])
test_alpha = np.full((100, 1), -0.830)
test_beta = np.full((100, 1), -0.617)
test_in = np.hstack((test_x, test_alpha, test_beta))
test_u = model(torch.Tensor(test_in).to(device))
X = test_x

Y = np.sin(test_alpha * X) + np.cos(test_beta * X) + 0.1 * X
# Out:
# Current device: cuda

# %%
C = test_u.cpu().detach().numpy()
plt.figure(figsize=(10, 8))
plt.plot(X, C, 'b-', label='PINN')
plt.plot(X, Y, 'r--', label='Answer')
plt.legend()

# %%
np.sqrt( np.sum((C-Y)**2) / np.sum(C**2) )
# Out:
# 0.13252834703931599

# %%
# steps = [ 1000 / len(val_loss['inner_loss']) * i for i in range(len(val_loss['inner_loss']))]
# idx = [100 * i for i in range(10)]
# loss = train_loss['inner_loss_f'][::100]
# plt.plot(val_loss['inner_loss'], label='loss')
plt.plot(np.mean(nrmse['nrmse_val'], axis=1), label='Val.')
plt.plot(np.mean(nrmse['nrmse_val_ood'], axis=1), label='Val. OOD')
plt.legend()
plt.title('FO-MAML Val. Poisson')
# plt.plot( loss)
# plt.plot(nrmse['nrmse_val'])
# plt.plot(nrmse['nrmse_val_ood'])
# plt.plot(train_loss['inner_loss'])

# %%
from train import *

# %%
epochs = 500
lr = 0.001

# %%
# loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse_set = train(epochs=epochs, lr=lr, i_size=100, b_size=100, f_size=1000, zero_shot=False, load=True, load_data='models/maml_burgers_5000.data', alpha_list=0.01 / np.pi, eqname='burgers')
loss_i, loss_b, loss_f, loss, model, val_loss, val_ood_loss, nrmse_set = train(epochs=epochs, lr=lr, i_size=0, b_size=2, f_size=10, zero_shot=False, load=True, load_data='maml.data', alpha_list=0.7, beta_list=-0.9, eqname='poisson')

# %%
# loss_i_2, loss_b_2, loss_f_2, loss_2, model_2, val_loss_2, val_ood_loss_2, nrmse_set_2 = train(epochs=epochs, lr=lr, i_size=100, b_size=100, f_size=1000, zero_shot=False, load=False, load_data='maml.data', alpha_list=0.01 / np.pi, eqname='burgers')
loss_i_2, loss_b_2, loss_f_2, loss_2, model_2, val_loss_2, val_ood_loss_2, nrmse_set_2 = train(epochs=epochs, lr=lr, i_size=0, b_size=2, f_size=10, zero_shot=False, load=False, load_data='maml.data', alpha_list=0.7, beta_list=-0.9, eqname='poisson')

# %%
plt.title('Loss Few shot')
plt.yscale('log')
plt.plot(loss, label='MAML')
plt.plot(loss_2, label='Random')
plt.legend()

# %%
plt.title('Relative error Few shot')
plt.yscale('log')
plt.plot(nrmse_set, label='MAML')
plt.plot(nrmse_set_2, label='Random')
plt.legend()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Current device:", device)
test_x = np.linspace(-1, 1, num=100).reshape(-1, 1)
# test_alpha = np.full((100, 1), alpha[2])
# test_beta = np.full((100, 1), beta[2])
test_alpha = np.full((100, 1), 0.7)
test_beta = np.full((100, 1), 0.7)
# test_in = np.hstack((test_x, test_alpha, test_beta))
test_u = model_2(torch.Tensor(test_x).to(device))
X = test_x

Y = np.sin(test_alpha * X) + np.cos(test_beta * X) + 0.1 * X

# %%
C = test_u.cpu().detach().numpy()
plt.figure(figsize=(10, 8))
plt.scatter(X, C, label='PINN')
plt.scatter(X, Y, label='Answer')
plt.legend()
plt.colorbar()

# %%
plt.plot(loss)
plt.plot(loss_2)

# %%
from burgers import *

# %%
vtn = 101
vxn = 101
nu = 0.01 / np.pi
vx = np.linspace(-1, 1, vxn)
vt = np.linspace(0, 1, vtn)

vu = burgers_viscous_time_exact1(nu, vxn, vx, vtn, vt)

x, t = np.meshgrid(vx, vt)
x = x.reshape(-1, 1)
t = t.reshape(-1, 1)

plt.scatter(x, t, c=vu, cmap='seismic')
plt.colorbar()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Current device:", device)

# %%
vtn = 101
vxn = 101
nu = 0.01 / np.pi
vx = np.linspace(-1, 1, vxn)
vt = np.linspace(0, 1, vtn)
x, t = np.meshgrid(vx, vt)
x = x.reshape(-1, 1)
t = t.reshape(-1, 1)
alpha = np.full((x.shape), nu)
pred = model_2(torch.Tensor(np.hstack((x, t))).to(device)).detach().cpu().numpy()
# pred = model(torch.Tensor(np.hstack((x, t))).to(device)).detach().cpu().numpy()
truth = burgers_viscous_time_exact1(nu, vxn, vx, vtn, vt).T.reshape(-1, 1)

# %%
plt.scatter(x, t, c=pred, cmap='seismic')
plt.colorbar()
